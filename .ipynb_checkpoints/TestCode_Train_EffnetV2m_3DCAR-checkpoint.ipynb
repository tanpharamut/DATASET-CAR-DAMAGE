# %%
import os
import tensorflow as tf
from efficientnet_v2 import *
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from tensorflow.keras import callbacks
import pandas as pd
from keras.utils import generic_utils
from efficientnet_v2 import get_preprocessing_layer
from keras import layers
from keras import models
from tensorflow.keras import optimizers
# Out:
# 2022-11-22 10:28:05.809188: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 10:28:05.911408: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-22 10:28:05.934874: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-22 10:28:06.368852: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kannika/yes/envs/tf/lib/
# 2022-11-22 10:28:06.368910: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kannika/yes/envs/tf/lib/
# 2022-11-22 10:28:06.368915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## 🚗 Train Fold2-8
#
# - NFold-1

# %%
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] ='false'
os.environ['XLA_PYTHON_CLIENT_ALLOCATOR']='platform'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="1"
tf_device='/gpu:0'

# %%
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

#Setting
BATCH_SIZE = 256
TARGET_SIZE = (480, 480)  # M variant expects images in shape (480, 480)
epochs = 5

# %%
#Train
database = pd.read_csv('/media/SSD/Data_photogram_Pcar/Dataset_3DCar.csv') #แก้ data เปลี่ยนตาม fold
trainframe = database[database['Fold'] != 'fold-1'].reset_index(drop=True)
base_dir = '/media/SSD/Data_photogram_Pcar/8-Fold/'
# os.chdir(base_dir)
# train_dir = os.path.join(base_dir, 'train')
print(trainframe.shape)
trainframe.head()
# Out:
# (351635, 11)
#    Unnamed: 0.1  Unnamed: 0    ID Damage   p  \
# 0             0           0  id10   Base  p1
# 1             1           1  id10   Base  p1
# 2             2           2  id10   Base  p1
# 3             3           3  id10   Base  p1
# 4             4           4  id10   Base  p1
#
#                                  FileName distance   Angle  \
# 0    id10-Base_p1_dis1.9_angle0_elev8.png   dis1.9  Angle0
# 1  id10-Base_p1_dis1.9_angle0_elev8D1.png   dis1.9  Angle0
# 2  id10-Base_p1_dis1.9_angle0_elev8D2.png   dis1.9  Angle0
# 3  id10-Base_p1_dis1.9_angle0_elev8D3.png   dis1.9  Angle0
# 4  id10-Base_p1_dis1.9_angle0_elev8D4.png   dis1.9  Angle0
#
#                                             img_path    Fold  \
# 0  /media/SSD/Data_photogram_car/id10/Base/p1/dis...  fold-4
# 1  /media/SSD/Data_photogram_car/id10/Base/p1/dis...  fold-4
# 2  /media/SSD/Data_photogram_car/id10/Base/p1/dis...  fold-4
# 3  /media/SSD/Data_photogram_car/id10/Base/p1/dis...  fold-4
# 4  /media/SSD/Data_photogram_car/id10/Base/p1/dis...  fold-4
#
#                                           path_train
# 0  /media/SSD/Data_photogram_Pcar/8-Fold/id10-Bas...
# 1  /media/SSD/Data_photogram_Pcar/8-Fold/id10-Bas...
# 2  /media/SSD/Data_photogram_Pcar/8-Fold/id10-Bas...
# 3  /media/SSD/Data_photogram_Pcar/8-Fold/id10-Bas...
# 4  /media/SSD/Data_photogram_Pcar/8-Fold/id10-Bas...

# %%
#validation
testframe = database[database['Fold'] == 'fold-1'].reset_index(drop=True) ###*** เปลี่ยนตาม fold
print(testframe.shape)
testframe.head()
# Out:
# (46332, 11)
#    Unnamed: 0.1  Unnamed: 0   ID Damage   p  \
# 0        198383      198383  id2   Base  p1
# 1        198384      198384  id2   Base  p1
# 2        198385      198385  id2   Base  p1
# 3        198386      198386  id2   Base  p1
# 4        198387      198387  id2   Base  p1
#
#                                 FileName distance   Angle  \
# 0    id2-Base_p1_dis1.8_angle0_elev8.png   dis1.8  Angle0
# 1  id2-Base_p1_dis1.8_angle0_elev8D1.png   dis1.8  Angle0
# 2  id2-Base_p1_dis1.8_angle0_elev8D2.png   dis1.8  Angle0
# 3  id2-Base_p1_dis1.8_angle0_elev8D3.png   dis1.8  Angle0
# 4  id2-Base_p1_dis1.8_angle0_elev8D4.png   dis1.8  Angle0
#
#                                             img_path    Fold  \
# 0  /media/SSD/Data_photogram_car/id2/Base/p1/dis1...  fold-1
# 1  /media/SSD/Data_photogram_car/id2/Base/p1/dis1...  fold-1
# 2  /media/SSD/Data_photogram_car/id2/Base/p1/dis1...  fold-1
# 3  /media/SSD/Data_photogram_car/id2/Base/p1/dis1...  fold-1
# 4  /media/SSD/Data_photogram_car/id2/Base/p1/dis1...  fold-1
#
#                                           path_train
# 0  /media/SSD/Data_photogram_Pcar/8-Fold/id2-Base...
# 1  /media/SSD/Data_photogram_Pcar/8-Fold/id2-Base...
# 2  /media/SSD/Data_photogram_Pcar/8-Fold/id2-Base...
# 3  /media/SSD/Data_photogram_Pcar/8-Fold/id2-Base...
# 4  /media/SSD/Data_photogram_Pcar/8-Fold/id2-Base...

# %%
## Create Model
base_model = EfficientNetV2M(input_shape=(TARGET_SIZE[0], TARGET_SIZE[1], 3),
                include_top=False, weights="imagenet-21k")  # Let's use pretrained on imagenet 21k and fine tuned on 1k weight variant.
height = width = base_model.input_shape[1]
input_shape = (height, width, 3)

### ****---create new model with a new classification layer
x = base_model.output 
global_average_layer = layers.GlobalAveragePooling2D(name = 'head_pooling')(x)
dropout_layer_1 = layers.Dropout(0.5,name = 'head_dropout')(global_average_layer)
prediction_layer = layers.Dense(15, activation='softmax',name = 'prediction_layer')(dropout_layer_1)  ##15 == Classes 15p

model = models.Model(inputs= base_model.input, outputs=prediction_layer) 
model.summary()
# Out:
# 2022-11-22 10:28:30.872737: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 10:28:31.679292: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-11-22 10:28:31.679323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 16911 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:65:00.0, compute capability: 8.6
# 2022-11-22 10:28:31.679841: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-11-22 10:28:31.679859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9294 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 240, 240, 24  648         ['input_1[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 240, 240, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 240, 240, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1-01_project_conv (Conv2D  (None, 240, 240, 24  5184       ['stem_activation[0][0]']
#  )                              )
#
#  block1-01_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-01_project_conv[0][0]']
#  malization)                    )
#
#  block1-01_project_activation (  (None, 240, 240, 24  0          ['block1-01_project_bn[0][0]']
#  Activation)                    )
#
#  block1-01_add (Add)            (None, 240, 240, 24  0           ['block1-01_project_activation[0]
#                                 )                                [0]',
#                                                                   'stem_activation[0][0]']
#
#  block1-02_project_conv (Conv2D  (None, 240, 240, 24  5184       ['block1-01_add[0][0]']
#  )                              )
#
#  block1-02_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-02_project_conv[0][0]']
#  malization)                    )
#
#  block1-02_project_activation (  (None, 240, 240, 24  0          ['block1-02_project_bn[0][0]']
#  Activation)                    )
#
#  block1-02_drop (Dropout)       (None, 240, 240, 24  0           ['block1-02_project_activation[0]
#                                 )                                [0]']
#
#  block1-02_add (Add)            (None, 240, 240, 24  0           ['block1-02_drop[0][0]',
#                                 )                                 'block1-01_add[0][0]']
#
#  block1-03_project_conv (Conv2D  (None, 240, 240, 24  5184       ['block1-02_add[0][0]']
#  )                              )
#
#  block1-03_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-03_project_conv[0][0]']
#  malization)                    )
#
#  block1-03_project_activation (  (None, 240, 240, 24  0          ['block1-03_project_bn[0][0]']
#  Activation)                    )
#
#  block1-03_drop (Dropout)       (None, 240, 240, 24  0           ['block1-03_project_activation[0]
#                                 )                                [0]']
#
#  block1-03_add (Add)            (None, 240, 240, 24  0           ['block1-03_drop[0][0]',
#                                 )                                 'block1-02_add[0][0]']
#
#  block2-01_expand_conv (Conv2D)  (None, 120, 120, 96  20736      ['block1-03_add[0][0]']
#                                 )
#
#  block2-01_expand_bn (BatchNorm  (None, 120, 120, 96  384        ['block2-01_expand_conv[0][0]']
#  alization)                     )
#
#  block2-01_expand_activation (A  (None, 120, 120, 96  0          ['block2-01_expand_bn[0][0]']
#  ctivation)                     )
#
#  block2-01_project_conv (Conv2D  (None, 120, 120, 48  4608       ['block2-01_expand_activation[0][
#  )                              )                                0]']
#
#  block2-01_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-01_project_conv[0][0]']
#  malization)                    )
#
#  block2-02_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-01_project_bn[0][0]']
#                                 2)
#
#  block2-02_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-02_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-02_expand_activation (A  (None, 120, 120, 19  0          ['block2-02_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-02_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-02_expand_activation[0][
#  )                              )                                0]']
#
#  block2-02_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-02_project_conv[0][0]']
#  malization)                    )
#
#  block2-02_drop (Dropout)       (None, 120, 120, 48  0           ['block2-02_project_bn[0][0]']
#                                 )
#
#  block2-02_add (Add)            (None, 120, 120, 48  0           ['block2-02_drop[0][0]',
#                                 )                                 'block2-01_project_bn[0][0]']
#
#  block2-03_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-02_add[0][0]']
#                                 2)
#
#  block2-03_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-03_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-03_expand_activation (A  (None, 120, 120, 19  0          ['block2-03_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-03_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-03_expand_activation[0][
#  )                              )                                0]']
#
#  block2-03_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-03_project_conv[0][0]']
#  malization)                    )
#
#  block2-03_drop (Dropout)       (None, 120, 120, 48  0           ['block2-03_project_bn[0][0]']
#                                 )
#
#  block2-03_add (Add)            (None, 120, 120, 48  0           ['block2-03_drop[0][0]',
#                                 )                                 'block2-02_add[0][0]']
#
#  block2-04_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-03_add[0][0]']
#                                 2)
#
#  block2-04_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-04_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-04_expand_activation (A  (None, 120, 120, 19  0          ['block2-04_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-04_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-04_expand_activation[0][
#  )                              )                                0]']
#
#  block2-04_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-04_project_conv[0][0]']
#  malization)                    )
#
#  block2-04_drop (Dropout)       (None, 120, 120, 48  0           ['block2-04_project_bn[0][0]']
#                                 )
#
#  block2-04_add (Add)            (None, 120, 120, 48  0           ['block2-04_drop[0][0]',
#                                 )                                 'block2-03_add[0][0]']
#
#  block2-05_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-04_add[0][0]']
#                                 2)
#
#  block2-05_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-05_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-05_expand_activation (A  (None, 120, 120, 19  0          ['block2-05_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-05_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-05_expand_activation[0][
#  )                              )                                0]']
#
#  block2-05_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-05_project_conv[0][0]']
#  malization)                    )
#
#  block2-05_drop (Dropout)       (None, 120, 120, 48  0           ['block2-05_project_bn[0][0]']
#                                 )
#
#  block2-05_add (Add)            (None, 120, 120, 48  0           ['block2-05_drop[0][0]',
#                                 )                                 'block2-04_add[0][0]']
#
#  block3-01_expand_conv (Conv2D)  (None, 60, 60, 192)  82944      ['block2-05_add[0][0]']
#
#  block3-01_expand_bn (BatchNorm  (None, 60, 60, 192)  768        ['block3-01_expand_conv[0][0]']
#  alization)
#
#  block3-01_expand_activation (A  (None, 60, 60, 192)  0          ['block3-01_expand_bn[0][0]']
#  ctivation)
#
#  block3-01_project_conv (Conv2D  (None, 60, 60, 80)  15360       ['block3-01_expand_activation[0][
#  )                                                               0]']
#
#  block3-01_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-01_project_conv[0][0]']
#  malization)
#
#  block3-02_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-01_project_bn[0][0]']
#
#  block3-02_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-02_expand_conv[0][0]']
#  alization)
#
#  block3-02_expand_activation (A  (None, 60, 60, 320)  0          ['block3-02_expand_bn[0][0]']
#  ctivation)
#
#  block3-02_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-02_expand_activation[0][
#  )                                                               0]']
#
#  block3-02_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-02_project_conv[0][0]']
#  malization)
#
#  block3-02_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-02_project_bn[0][0]']
#
#  block3-02_add (Add)            (None, 60, 60, 80)   0           ['block3-02_drop[0][0]',
#                                                                   'block3-01_project_bn[0][0]']
#
#  block3-03_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-02_add[0][0]']
#
#  block3-03_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-03_expand_conv[0][0]']
#  alization)
#
#  block3-03_expand_activation (A  (None, 60, 60, 320)  0          ['block3-03_expand_bn[0][0]']
#  ctivation)
#
#  block3-03_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-03_expand_activation[0][
#  )                                                               0]']
#
#  block3-03_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-03_project_conv[0][0]']
#  malization)
#
#  block3-03_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-03_project_bn[0][0]']
#
#  block3-03_add (Add)            (None, 60, 60, 80)   0           ['block3-03_drop[0][0]',
#                                                                   'block3-02_add[0][0]']
#
#  block3-04_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-03_add[0][0]']
#
#  block3-04_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-04_expand_conv[0][0]']
#  alization)
#
#  block3-04_expand_activation (A  (None, 60, 60, 320)  0          ['block3-04_expand_bn[0][0]']
#  ctivation)
#
#  block3-04_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-04_expand_activation[0][
#  )                                                               0]']
#
#  block3-04_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-04_project_conv[0][0]']
#  malization)
#
#  block3-04_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-04_project_bn[0][0]']
#
#  block3-04_add (Add)            (None, 60, 60, 80)   0           ['block3-04_drop[0][0]',
#                                                                   'block3-03_add[0][0]']
#
#  block3-05_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-04_add[0][0]']
#
#  block3-05_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-05_expand_conv[0][0]']
#  alization)
#
#  block3-05_expand_activation (A  (None, 60, 60, 320)  0          ['block3-05_expand_bn[0][0]']
#  ctivation)
#
#  block3-05_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-05_expand_activation[0][
#  )                                                               0]']
#
#  block3-05_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-05_project_conv[0][0]']
#  malization)
#
#  block3-05_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-05_project_bn[0][0]']
#
#  block3-05_add (Add)            (None, 60, 60, 80)   0           ['block3-05_drop[0][0]',
#                                                                   'block3-04_add[0][0]']
#
#  block4-01_expand_conv (Conv2D)  (None, 60, 60, 320)  25600      ['block3-05_add[0][0]']
#  block4-01_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block4-01_expand_conv[0][0]']
#  alization)
#
#  block4-01_expand_activation (A  (None, 60, 60, 320)  0          ['block4-01_expand_bn[0][0]']
#  ctivation)
#
#  block4-01_dwconv2 (DepthwiseCo  (None, 30, 30, 320)  2880       ['block4-01_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-01_bn (BatchNormalizati  (None, 30, 30, 320)  1280       ['block4-01_dwconv2[0][0]']
#  on)
#
#  block4-01_activation (Activati  (None, 30, 30, 320)  0          ['block4-01_bn[0][0]']
#  on)
#
#  block4-01_se_squeeze (GlobalAv  (None, 320)         0           ['block4-01_activation[0][0]']
#  eragePooling2D)
#
#  block4-01_se_reshape (Reshape)  (None, 1, 1, 320)   0           ['block4-01_se_squeeze[0][0]']
#
#  block4-01_se_reduce (Conv2D)   (None, 1, 1, 20)     6420        ['block4-01_se_reshape[0][0]']
#
#  block4-01_se_expand (Conv2D)   (None, 1, 1, 320)    6720        ['block4-01_se_reduce[0][0]']
#
#  block4-01_se_excite (Multiply)  (None, 30, 30, 320)  0          ['block4-01_activation[0][0]',
#                                                                   'block4-01_se_expand[0][0]']
#
#  block4-01_project_conv (Conv2D  (None, 30, 30, 160)  51200      ['block4-01_se_excite[0][0]']
#  )
#
#  block4-01_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-01_project_conv[0][0]']
#  malization)
#
#  block4-02_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-01_project_bn[0][0]']
#
#  block4-02_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-02_expand_conv[0][0]']
#  alization)
#
#  block4-02_expand_activation (A  (None, 30, 30, 640)  0          ['block4-02_expand_bn[0][0]']
#  ctivation)
#
#  block4-02_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-02_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-02_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-02_dwconv2[0][0]']
#  on)
#
#  block4-02_activation (Activati  (None, 30, 30, 640)  0          ['block4-02_bn[0][0]']
#  on)
#
#  block4-02_se_squeeze (GlobalAv  (None, 640)         0           ['block4-02_activation[0][0]']
#  eragePooling2D)
#
#  block4-02_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-02_se_squeeze[0][0]']
#
#  block4-02_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-02_se_reshape[0][0]']
#
#  block4-02_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-02_se_reduce[0][0]']
#
#  block4-02_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-02_activation[0][0]',
#                                                                   'block4-02_se_expand[0][0]']
#
#  block4-02_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-02_se_excite[0][0]']
#  )
#
#  block4-02_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-02_project_conv[0][0]']
#  malization)
#
#  block4-02_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-02_project_bn[0][0]']
#
#  block4-02_add (Add)            (None, 30, 30, 160)  0           ['block4-02_drop[0][0]',
#                                                                   'block4-01_project_bn[0][0]']
#
#  block4-03_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-02_add[0][0]']
#
#  block4-03_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-03_expand_conv[0][0]']
#  alization)
#
#  block4-03_expand_activation (A  (None, 30, 30, 640)  0          ['block4-03_expand_bn[0][0]']
#  ctivation)
#
#  block4-03_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-03_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-03_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-03_dwconv2[0][0]']
#  on)
#
#  block4-03_activation (Activati  (None, 30, 30, 640)  0          ['block4-03_bn[0][0]']
#  on)
#
#  block4-03_se_squeeze (GlobalAv  (None, 640)         0           ['block4-03_activation[0][0]']
#  eragePooling2D)
#
#  block4-03_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-03_se_squeeze[0][0]']
#
#  block4-03_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-03_se_reshape[0][0]']
#
#  block4-03_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-03_se_reduce[0][0]']
#
#  block4-03_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-03_activation[0][0]',
#                                                                   'block4-03_se_expand[0][0]']
#
#  block4-03_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-03_se_excite[0][0]']
#  )
#
#  block4-03_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-03_project_conv[0][0]']
#  malization)
#
#  block4-03_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-03_project_bn[0][0]']
#
#  block4-03_add (Add)            (None, 30, 30, 160)  0           ['block4-03_drop[0][0]',
#                                                                   'block4-02_add[0][0]']
#
#  block4-04_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-03_add[0][0]']
#
#  block4-04_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-04_expand_conv[0][0]']
#  alization)
#
#  block4-04_expand_activation (A  (None, 30, 30, 640)  0          ['block4-04_expand_bn[0][0]']
#  ctivation)
#
#  block4-04_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-04_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-04_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-04_dwconv2[0][0]']
#  on)
#
#  block4-04_activation (Activati  (None, 30, 30, 640)  0          ['block4-04_bn[0][0]']
#  on)
#
#  block4-04_se_squeeze (GlobalAv  (None, 640)         0           ['block4-04_activation[0][0]']
#  eragePooling2D)
#
#  block4-04_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-04_se_squeeze[0][0]']
#
#  block4-04_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-04_se_reshape[0][0]']
#
#  block4-04_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-04_se_reduce[0][0]']
#
#  block4-04_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-04_activation[0][0]',
#                                                                   'block4-04_se_expand[0][0]']
#
#  block4-04_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-04_se_excite[0][0]']
#  )
#
#  block4-04_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-04_project_conv[0][0]']
#  malization)
#
#  block4-04_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-04_project_bn[0][0]']
#
#  block4-04_add (Add)            (None, 30, 30, 160)  0           ['block4-04_drop[0][0]',
#                                                                   'block4-03_add[0][0]']
#
#  block4-05_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-04_add[0][0]']
#
#  block4-05_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-05_expand_conv[0][0]']
#  alization)
#
#  block4-05_expand_activation (A  (None, 30, 30, 640)  0          ['block4-05_expand_bn[0][0]']
#  ctivation)
#
#  block4-05_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-05_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-05_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-05_dwconv2[0][0]']
#  on)
#
#  block4-05_activation (Activati  (None, 30, 30, 640)  0          ['block4-05_bn[0][0]']
#  on)
#
#  block4-05_se_squeeze (GlobalAv  (None, 640)         0           ['block4-05_activation[0][0]']
#  eragePooling2D)
#
#  block4-05_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-05_se_squeeze[0][0]']
#
#  block4-05_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-05_se_reshape[0][0]']
#
#  block4-05_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-05_se_reduce[0][0]']
#
#  block4-05_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-05_activation[0][0]',
#                                                                   'block4-05_se_expand[0][0]']
#
#  block4-05_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-05_se_excite[0][0]']
#  )
#
#  block4-05_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-05_project_conv[0][0]']
#  malization)
#
#  block4-05_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-05_project_bn[0][0]']
#
#  block4-05_add (Add)            (None, 30, 30, 160)  0           ['block4-05_drop[0][0]',
#                                                                   'block4-04_add[0][0]']
#
#  block4-06_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-05_add[0][0]']
#
#  block4-06_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-06_expand_conv[0][0]']
#  alization)
#
#  block4-06_expand_activation (A  (None, 30, 30, 640)  0          ['block4-06_expand_bn[0][0]']
#  ctivation)
#
#  block4-06_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-06_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-06_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-06_dwconv2[0][0]']
#  on)
#
#  block4-06_activation (Activati  (None, 30, 30, 640)  0          ['block4-06_bn[0][0]']
#  on)
#
#  block4-06_se_squeeze (GlobalAv  (None, 640)         0           ['block4-06_activation[0][0]']
#  eragePooling2D)
#
#  block4-06_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-06_se_squeeze[0][0]']
#
#  block4-06_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-06_se_reshape[0][0]']
#
#  block4-06_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-06_se_reduce[0][0]']
#
#  block4-06_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-06_activation[0][0]',
#                                                                   'block4-06_se_expand[0][0]']
#
#  block4-06_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-06_se_excite[0][0]']
#  )
# ...
#
#  block7-02_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-02_se_squeeze[0][0]']
#
#  block7-02_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-02_se_reshape[0][0]']
#
#  block7-02_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-02_se_reduce[0][0]']
#
#  block7-02_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-02_activation[0][0]',
#                                 )                                 'block7-02_se_expand[0][0]']
#
#  block7-02_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-02_se_excite[0][0]']
#  )
#
#  block7-02_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-02_project_conv[0][0]']
#  malization)
#
#  block7-02_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-02_project_bn[0][0]']
#
#  block7-02_add (Add)            (None, 15, 15, 512)  0           ['block7-02_drop[0][0]',
#                                                                   'block7-01_project_bn[0][0]']
#
#  block7-03_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-02_add[0][0]']
#                                 )
#
#  block7-03_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-03_expand_conv[0][0]']
#  alization)                     )
#
#  block7-03_expand_activation (A  (None, 15, 15, 3072  0          ['block7-03_expand_bn[0][0]']
#  ctivation)                     )
#  block7-03_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-03_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-03_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-03_dwconv2[0][0]']
#  on)                            )
#
#  block7-03_activation (Activati  (None, 15, 15, 3072  0          ['block7-03_bn[0][0]']
#  on)                            )
#
#  block7-03_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-03_activation[0][0]']
#  eragePooling2D)
#
#  block7-03_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-03_se_squeeze[0][0]']
#
#  block7-03_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-03_se_reshape[0][0]']
#
#  block7-03_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-03_se_reduce[0][0]']
#
#  block7-03_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-03_activation[0][0]',
#                                 )                                 'block7-03_se_expand[0][0]']
#
#  block7-03_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-03_se_excite[0][0]']
#  )
#
#  block7-03_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-03_project_conv[0][0]']
#  malization)
#
#  block7-03_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-03_project_bn[0][0]']
#
#  block7-03_add (Add)            (None, 15, 15, 512)  0           ['block7-03_drop[0][0]',
#                                                                   'block7-02_add[0][0]']
#
#  block7-04_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-03_add[0][0]']
#                                 )
#
#  block7-04_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-04_expand_conv[0][0]']
#  alization)                     )
#
#  block7-04_expand_activation (A  (None, 15, 15, 3072  0          ['block7-04_expand_bn[0][0]']
#  ctivation)                     )
#
#  block7-04_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-04_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-04_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-04_dwconv2[0][0]']
#  on)                            )
#
#  block7-04_activation (Activati  (None, 15, 15, 3072  0          ['block7-04_bn[0][0]']
#  on)                            )
#
#  block7-04_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-04_activation[0][0]']
#  eragePooling2D)
#
#  block7-04_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-04_se_squeeze[0][0]']
#
#  block7-04_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-04_se_reshape[0][0]']
#
#  block7-04_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-04_se_reduce[0][0]']
#
#  block7-04_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-04_activation[0][0]',
#                                 )                                 'block7-04_se_expand[0][0]']
#
#  block7-04_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-04_se_excite[0][0]']
#  )
#
#  block7-04_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-04_project_conv[0][0]']
#  malization)
#
#  block7-04_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-04_project_bn[0][0]']
#
#  block7-04_add (Add)            (None, 15, 15, 512)  0           ['block7-04_drop[0][0]',
#                                                                   'block7-03_add[0][0]']
#
#  block7-05_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-04_add[0][0]']
#                                 )
#
#  block7-05_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-05_expand_conv[0][0]']
#  alization)                     )
#
#  block7-05_expand_activation (A  (None, 15, 15, 3072  0          ['block7-05_expand_bn[0][0]']
#  ctivation)                     )
#
#  block7-05_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-05_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-05_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-05_dwconv2[0][0]']
#  on)                            )
#
#  block7-05_activation (Activati  (None, 15, 15, 3072  0          ['block7-05_bn[0][0]']
#  on)                            )
#
#  block7-05_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-05_activation[0][0]']
#  eragePooling2D)
#
#  block7-05_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-05_se_squeeze[0][0]']
#
#  block7-05_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-05_se_reshape[0][0]']
#
#  block7-05_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-05_se_reduce[0][0]']
#
#  block7-05_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-05_activation[0][0]',
#                                 )                                 'block7-05_se_expand[0][0]']
#
#  block7-05_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-05_se_excite[0][0]']
#  )
#
#  block7-05_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-05_project_conv[0][0]']
#  malization)
#
#  block7-05_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-05_project_bn[0][0]']
#
#  block7-05_add (Add)            (None, 15, 15, 512)  0           ['block7-05_drop[0][0]',
#                                                                   'block7-04_add[0][0]']
#
#  top_conv (Conv2D)              (None, 15, 15, 1280  655360      ['block7-05_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 15, 15, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 15, 15, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  head_pooling (GlobalAveragePoo  (None, 1280)        0           ['top_activation[0][0]']
#  ling2D)
#
#  head_dropout (Dropout)         (None, 1280)         0           ['head_pooling[0][0]']
#
#  prediction_layer (Dense)       (None, 15)           19215       ['head_dropout[0][0]']
#
# ==================================================================================================
# Total params: 53,169,603
# Trainable params: 52,877,571
# Non-trainable params: 292,032
# __________________________________________________________________________________________________

# %%
##Freeze
print('This is the number of trainable layers '
          'before freezing the conv base:', len(model.trainable_weights))
for layer in base_model.layers:
    layer.trainable = False
print('This is the number of trainable layers '
          'after freezing the conv base:', len(model.trainable_weights))
print('-'*80)
# Out:
# This is the number of trainable layers before freezing the conv base: 649
# This is the number of trainable layers after freezing the conv base: 2
# --------------------------------------------------------------------------------

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 240, 240, 24  648         ['input_1[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 240, 240, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 240, 240, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1-01_project_conv (Conv2D  (None, 240, 240, 24  5184       ['stem_activation[0][0]']
#  )                              )
#
#  block1-01_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-01_project_conv[0][0]']
#  malization)                    )
#
#  block1-01_project_activation (  (None, 240, 240, 24  0          ['block1-01_project_bn[0][0]']
#  Activation)                    )
#
#  block1-01_add (Add)            (None, 240, 240, 24  0           ['block1-01_project_activation[0]
#                                 )                                [0]',
#                                                                   'stem_activation[0][0]']
#
#  block1-02_project_conv (Conv2D  (None, 240, 240, 24  5184       ['block1-01_add[0][0]']
#  )                              )
#
#  block1-02_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-02_project_conv[0][0]']
#  malization)                    )
#
#  block1-02_project_activation (  (None, 240, 240, 24  0          ['block1-02_project_bn[0][0]']
#  Activation)                    )
#
#  block1-02_drop (Dropout)       (None, 240, 240, 24  0           ['block1-02_project_activation[0]
#                                 )                                [0]']
#
#  block1-02_add (Add)            (None, 240, 240, 24  0           ['block1-02_drop[0][0]',
#                                 )                                 'block1-01_add[0][0]']
#
#  block1-03_project_conv (Conv2D  (None, 240, 240, 24  5184       ['block1-02_add[0][0]']
#  )                              )
#
#  block1-03_project_bn (BatchNor  (None, 240, 240, 24  96         ['block1-03_project_conv[0][0]']
#  malization)                    )
#
#  block1-03_project_activation (  (None, 240, 240, 24  0          ['block1-03_project_bn[0][0]']
#  Activation)                    )
#
#  block1-03_drop (Dropout)       (None, 240, 240, 24  0           ['block1-03_project_activation[0]
#                                 )                                [0]']
#
#  block1-03_add (Add)            (None, 240, 240, 24  0           ['block1-03_drop[0][0]',
#                                 )                                 'block1-02_add[0][0]']
#
#  block2-01_expand_conv (Conv2D)  (None, 120, 120, 96  20736      ['block1-03_add[0][0]']
#                                 )
#
#  block2-01_expand_bn (BatchNorm  (None, 120, 120, 96  384        ['block2-01_expand_conv[0][0]']
#  alization)                     )
#
#  block2-01_expand_activation (A  (None, 120, 120, 96  0          ['block2-01_expand_bn[0][0]']
#  ctivation)                     )
#
#  block2-01_project_conv (Conv2D  (None, 120, 120, 48  4608       ['block2-01_expand_activation[0][
#  )                              )                                0]']
#
#  block2-01_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-01_project_conv[0][0]']
#  malization)                    )
#
#  block2-02_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-01_project_bn[0][0]']
#                                 2)
#
#  block2-02_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-02_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-02_expand_activation (A  (None, 120, 120, 19  0          ['block2-02_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-02_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-02_expand_activation[0][
#  )                              )                                0]']
#
#  block2-02_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-02_project_conv[0][0]']
#  malization)                    )
#
#  block2-02_drop (Dropout)       (None, 120, 120, 48  0           ['block2-02_project_bn[0][0]']
#                                 )
#
#  block2-02_add (Add)            (None, 120, 120, 48  0           ['block2-02_drop[0][0]',
#                                 )                                 'block2-01_project_bn[0][0]']
#
#  block2-03_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-02_add[0][0]']
#                                 2)
#
#  block2-03_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-03_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-03_expand_activation (A  (None, 120, 120, 19  0          ['block2-03_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-03_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-03_expand_activation[0][
#  )                              )                                0]']
#
#  block2-03_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-03_project_conv[0][0]']
#  malization)                    )
#
#  block2-03_drop (Dropout)       (None, 120, 120, 48  0           ['block2-03_project_bn[0][0]']
#                                 )
#
#  block2-03_add (Add)            (None, 120, 120, 48  0           ['block2-03_drop[0][0]',
#                                 )                                 'block2-02_add[0][0]']
#
#  block2-04_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-03_add[0][0]']
#                                 2)
#
#  block2-04_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-04_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-04_expand_activation (A  (None, 120, 120, 19  0          ['block2-04_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-04_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-04_expand_activation[0][
#  )                              )                                0]']
#
#  block2-04_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-04_project_conv[0][0]']
#  malization)                    )
#
#  block2-04_drop (Dropout)       (None, 120, 120, 48  0           ['block2-04_project_bn[0][0]']
#                                 )
#
#  block2-04_add (Add)            (None, 120, 120, 48  0           ['block2-04_drop[0][0]',
#                                 )                                 'block2-03_add[0][0]']
#
#  block2-05_expand_conv (Conv2D)  (None, 120, 120, 19  82944      ['block2-04_add[0][0]']
#                                 2)
#
#  block2-05_expand_bn (BatchNorm  (None, 120, 120, 19  768        ['block2-05_expand_conv[0][0]']
#  alization)                     2)
#
#  block2-05_expand_activation (A  (None, 120, 120, 19  0          ['block2-05_expand_bn[0][0]']
#  ctivation)                     2)
#
#  block2-05_project_conv (Conv2D  (None, 120, 120, 48  9216       ['block2-05_expand_activation[0][
#  )                              )                                0]']
#
#  block2-05_project_bn (BatchNor  (None, 120, 120, 48  192        ['block2-05_project_conv[0][0]']
#  malization)                    )
#
#  block2-05_drop (Dropout)       (None, 120, 120, 48  0           ['block2-05_project_bn[0][0]']
#                                 )
#
#  block2-05_add (Add)            (None, 120, 120, 48  0           ['block2-05_drop[0][0]',
#                                 )                                 'block2-04_add[0][0]']
#
#  block3-01_expand_conv (Conv2D)  (None, 60, 60, 192)  82944      ['block2-05_add[0][0]']
#
#  block3-01_expand_bn (BatchNorm  (None, 60, 60, 192)  768        ['block3-01_expand_conv[0][0]']
#  alization)
#
#  block3-01_expand_activation (A  (None, 60, 60, 192)  0          ['block3-01_expand_bn[0][0]']
#  ctivation)
#
#  block3-01_project_conv (Conv2D  (None, 60, 60, 80)  15360       ['block3-01_expand_activation[0][
#  )                                                               0]']
#
#  block3-01_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-01_project_conv[0][0]']
#  malization)
#
#  block3-02_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-01_project_bn[0][0]']
#
#  block3-02_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-02_expand_conv[0][0]']
#  alization)
#
#  block3-02_expand_activation (A  (None, 60, 60, 320)  0          ['block3-02_expand_bn[0][0]']
#  ctivation)
#
#  block3-02_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-02_expand_activation[0][
#  )                                                               0]']
#
#  block3-02_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-02_project_conv[0][0]']
#  malization)
#
#  block3-02_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-02_project_bn[0][0]']
#
#  block3-02_add (Add)            (None, 60, 60, 80)   0           ['block3-02_drop[0][0]',
#                                                                   'block3-01_project_bn[0][0]']
#
#  block3-03_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-02_add[0][0]']
#
#  block3-03_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-03_expand_conv[0][0]']
#  alization)
#
#  block3-03_expand_activation (A  (None, 60, 60, 320)  0          ['block3-03_expand_bn[0][0]']
#  ctivation)
#
#  block3-03_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-03_expand_activation[0][
#  )                                                               0]']
#
#  block3-03_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-03_project_conv[0][0]']
#  malization)
#
#  block3-03_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-03_project_bn[0][0]']
#
#  block3-03_add (Add)            (None, 60, 60, 80)   0           ['block3-03_drop[0][0]',
#                                                                   'block3-02_add[0][0]']
#
#  block3-04_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-03_add[0][0]']
#
#  block3-04_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-04_expand_conv[0][0]']
#  alization)
#
#  block3-04_expand_activation (A  (None, 60, 60, 320)  0          ['block3-04_expand_bn[0][0]']
#  ctivation)
#
#  block3-04_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-04_expand_activation[0][
#  )                                                               0]']
#
#  block3-04_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-04_project_conv[0][0]']
#  malization)
#
#  block3-04_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-04_project_bn[0][0]']
#
#  block3-04_add (Add)            (None, 60, 60, 80)   0           ['block3-04_drop[0][0]',
#                                                                   'block3-03_add[0][0]']
#
#  block3-05_expand_conv (Conv2D)  (None, 60, 60, 320)  230400     ['block3-04_add[0][0]']
#
#  block3-05_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block3-05_expand_conv[0][0]']
#  alization)
#
#  block3-05_expand_activation (A  (None, 60, 60, 320)  0          ['block3-05_expand_bn[0][0]']
#  ctivation)
#
#  block3-05_project_conv (Conv2D  (None, 60, 60, 80)  25600       ['block3-05_expand_activation[0][
#  )                                                               0]']
#
#  block3-05_project_bn (BatchNor  (None, 60, 60, 80)  320         ['block3-05_project_conv[0][0]']
#  malization)
#
#  block3-05_drop (Dropout)       (None, 60, 60, 80)   0           ['block3-05_project_bn[0][0]']
#
#  block3-05_add (Add)            (None, 60, 60, 80)   0           ['block3-05_drop[0][0]',
#                                                                   'block3-04_add[0][0]']
#
#  block4-01_expand_conv (Conv2D)  (None, 60, 60, 320)  25600      ['block3-05_add[0][0]']
#  block4-01_expand_bn (BatchNorm  (None, 60, 60, 320)  1280       ['block4-01_expand_conv[0][0]']
#  alization)
#
#  block4-01_expand_activation (A  (None, 60, 60, 320)  0          ['block4-01_expand_bn[0][0]']
#  ctivation)
#
#  block4-01_dwconv2 (DepthwiseCo  (None, 30, 30, 320)  2880       ['block4-01_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-01_bn (BatchNormalizati  (None, 30, 30, 320)  1280       ['block4-01_dwconv2[0][0]']
#  on)
#
#  block4-01_activation (Activati  (None, 30, 30, 320)  0          ['block4-01_bn[0][0]']
#  on)
#
#  block4-01_se_squeeze (GlobalAv  (None, 320)         0           ['block4-01_activation[0][0]']
#  eragePooling2D)
#
#  block4-01_se_reshape (Reshape)  (None, 1, 1, 320)   0           ['block4-01_se_squeeze[0][0]']
#
#  block4-01_se_reduce (Conv2D)   (None, 1, 1, 20)     6420        ['block4-01_se_reshape[0][0]']
#
#  block4-01_se_expand (Conv2D)   (None, 1, 1, 320)    6720        ['block4-01_se_reduce[0][0]']
#
#  block4-01_se_excite (Multiply)  (None, 30, 30, 320)  0          ['block4-01_activation[0][0]',
#                                                                   'block4-01_se_expand[0][0]']
#
#  block4-01_project_conv (Conv2D  (None, 30, 30, 160)  51200      ['block4-01_se_excite[0][0]']
#  )
#
#  block4-01_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-01_project_conv[0][0]']
#  malization)
#
#  block4-02_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-01_project_bn[0][0]']
#
#  block4-02_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-02_expand_conv[0][0]']
#  alization)
#
#  block4-02_expand_activation (A  (None, 30, 30, 640)  0          ['block4-02_expand_bn[0][0]']
#  ctivation)
#
#  block4-02_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-02_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-02_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-02_dwconv2[0][0]']
#  on)
#
#  block4-02_activation (Activati  (None, 30, 30, 640)  0          ['block4-02_bn[0][0]']
#  on)
#
#  block4-02_se_squeeze (GlobalAv  (None, 640)         0           ['block4-02_activation[0][0]']
#  eragePooling2D)
#
#  block4-02_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-02_se_squeeze[0][0]']
#
#  block4-02_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-02_se_reshape[0][0]']
#
#  block4-02_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-02_se_reduce[0][0]']
#
#  block4-02_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-02_activation[0][0]',
#                                                                   'block4-02_se_expand[0][0]']
#
#  block4-02_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-02_se_excite[0][0]']
#  )
#
#  block4-02_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-02_project_conv[0][0]']
#  malization)
#
#  block4-02_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-02_project_bn[0][0]']
#
#  block4-02_add (Add)            (None, 30, 30, 160)  0           ['block4-02_drop[0][0]',
#                                                                   'block4-01_project_bn[0][0]']
#
#  block4-03_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-02_add[0][0]']
#
#  block4-03_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-03_expand_conv[0][0]']
#  alization)
#
#  block4-03_expand_activation (A  (None, 30, 30, 640)  0          ['block4-03_expand_bn[0][0]']
#  ctivation)
#
#  block4-03_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-03_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-03_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-03_dwconv2[0][0]']
#  on)
#
#  block4-03_activation (Activati  (None, 30, 30, 640)  0          ['block4-03_bn[0][0]']
#  on)
#
#  block4-03_se_squeeze (GlobalAv  (None, 640)         0           ['block4-03_activation[0][0]']
#  eragePooling2D)
#
#  block4-03_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-03_se_squeeze[0][0]']
#
#  block4-03_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-03_se_reshape[0][0]']
#
#  block4-03_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-03_se_reduce[0][0]']
#
#  block4-03_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-03_activation[0][0]',
#                                                                   'block4-03_se_expand[0][0]']
#
#  block4-03_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-03_se_excite[0][0]']
#  )
#
#  block4-03_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-03_project_conv[0][0]']
#  malization)
#
#  block4-03_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-03_project_bn[0][0]']
#
#  block4-03_add (Add)            (None, 30, 30, 160)  0           ['block4-03_drop[0][0]',
#                                                                   'block4-02_add[0][0]']
#
#  block4-04_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-03_add[0][0]']
#
#  block4-04_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-04_expand_conv[0][0]']
#  alization)
#
#  block4-04_expand_activation (A  (None, 30, 30, 640)  0          ['block4-04_expand_bn[0][0]']
#  ctivation)
#
#  block4-04_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-04_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-04_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-04_dwconv2[0][0]']
#  on)
#
#  block4-04_activation (Activati  (None, 30, 30, 640)  0          ['block4-04_bn[0][0]']
#  on)
#
#  block4-04_se_squeeze (GlobalAv  (None, 640)         0           ['block4-04_activation[0][0]']
#  eragePooling2D)
#
#  block4-04_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-04_se_squeeze[0][0]']
#
#  block4-04_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-04_se_reshape[0][0]']
#
#  block4-04_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-04_se_reduce[0][0]']
#
#  block4-04_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-04_activation[0][0]',
#                                                                   'block4-04_se_expand[0][0]']
#
#  block4-04_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-04_se_excite[0][0]']
#  )
#
#  block4-04_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-04_project_conv[0][0]']
#  malization)
#
#  block4-04_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-04_project_bn[0][0]']
#
#  block4-04_add (Add)            (None, 30, 30, 160)  0           ['block4-04_drop[0][0]',
#                                                                   'block4-03_add[0][0]']
#
#  block4-05_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-04_add[0][0]']
#
#  block4-05_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-05_expand_conv[0][0]']
#  alization)
#
#  block4-05_expand_activation (A  (None, 30, 30, 640)  0          ['block4-05_expand_bn[0][0]']
#  ctivation)
#
#  block4-05_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-05_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-05_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-05_dwconv2[0][0]']
#  on)
#
#  block4-05_activation (Activati  (None, 30, 30, 640)  0          ['block4-05_bn[0][0]']
#  on)
#
#  block4-05_se_squeeze (GlobalAv  (None, 640)         0           ['block4-05_activation[0][0]']
#  eragePooling2D)
#
#  block4-05_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-05_se_squeeze[0][0]']
#
#  block4-05_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-05_se_reshape[0][0]']
#
#  block4-05_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-05_se_reduce[0][0]']
#
#  block4-05_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-05_activation[0][0]',
#                                                                   'block4-05_se_expand[0][0]']
#
#  block4-05_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-05_se_excite[0][0]']
#  )
#
#  block4-05_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-05_project_conv[0][0]']
#  malization)
#
#  block4-05_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-05_project_bn[0][0]']
#
#  block4-05_add (Add)            (None, 30, 30, 160)  0           ['block4-05_drop[0][0]',
#                                                                   'block4-04_add[0][0]']
#
#  block4-06_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-05_add[0][0]']
#
#  block4-06_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-06_expand_conv[0][0]']
#  alization)
#
#  block4-06_expand_activation (A  (None, 30, 30, 640)  0          ['block4-06_expand_bn[0][0]']
#  ctivation)
#
#  block4-06_dwconv2 (DepthwiseCo  (None, 30, 30, 640)  5760       ['block4-06_expand_activation[0][
#  nv2D)                                                           0]']
#
#  block4-06_bn (BatchNormalizati  (None, 30, 30, 640)  2560       ['block4-06_dwconv2[0][0]']
#  on)
#
#  block4-06_activation (Activati  (None, 30, 30, 640)  0          ['block4-06_bn[0][0]']
#  on)
#
#  block4-06_se_squeeze (GlobalAv  (None, 640)         0           ['block4-06_activation[0][0]']
#  eragePooling2D)
#
#  block4-06_se_reshape (Reshape)  (None, 1, 1, 640)   0           ['block4-06_se_squeeze[0][0]']
#
#  block4-06_se_reduce (Conv2D)   (None, 1, 1, 40)     25640       ['block4-06_se_reshape[0][0]']
#
#  block4-06_se_expand (Conv2D)   (None, 1, 1, 640)    26240       ['block4-06_se_reduce[0][0]']
#
#  block4-06_se_excite (Multiply)  (None, 30, 30, 640)  0          ['block4-06_activation[0][0]',
#                                                                   'block4-06_se_expand[0][0]']
#
#  block4-06_project_conv (Conv2D  (None, 30, 30, 160)  102400     ['block4-06_se_excite[0][0]']
#  )
#
#  block4-06_project_bn (BatchNor  (None, 30, 30, 160)  640        ['block4-06_project_conv[0][0]']
#  malization)
#
#  block4-06_drop (Dropout)       (None, 30, 30, 160)  0           ['block4-06_project_bn[0][0]']
#
#  block4-06_add (Add)            (None, 30, 30, 160)  0           ['block4-06_drop[0][0]',
#                                                                   'block4-05_add[0][0]']
#
#  block4-07_expand_conv (Conv2D)  (None, 30, 30, 640)  102400     ['block4-06_add[0][0]']
#
#  block4-07_expand_bn (BatchNorm  (None, 30, 30, 640)  2560       ['block4-07_expand_conv[0][0]']
#  alization)
#
# ...
#
#  block7-02_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-02_se_squeeze[0][0]']
#
#  block7-02_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-02_se_reshape[0][0]']
#
#  block7-02_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-02_se_reduce[0][0]']
#
#  block7-02_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-02_activation[0][0]',
#                                 )                                 'block7-02_se_expand[0][0]']
#
#  block7-02_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-02_se_excite[0][0]']
#  )
#
#  block7-02_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-02_project_conv[0][0]']
#  malization)
#
#  block7-02_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-02_project_bn[0][0]']
#
#  block7-02_add (Add)            (None, 15, 15, 512)  0           ['block7-02_drop[0][0]',
#                                                                   'block7-01_project_bn[0][0]']
#
#  block7-03_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-02_add[0][0]']
#                                 )
#
#  block7-03_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-03_expand_conv[0][0]']
#  alization)                     )
#
#  block7-03_expand_activation (A  (None, 15, 15, 3072  0          ['block7-03_expand_bn[0][0]']
#  ctivation)                     )
#  block7-03_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-03_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-03_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-03_dwconv2[0][0]']
#  on)                            )
#
#  block7-03_activation (Activati  (None, 15, 15, 3072  0          ['block7-03_bn[0][0]']
#  on)                            )
#
#  block7-03_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-03_activation[0][0]']
#  eragePooling2D)
#
#  block7-03_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-03_se_squeeze[0][0]']
#
#  block7-03_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-03_se_reshape[0][0]']
#
#  block7-03_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-03_se_reduce[0][0]']
#
#  block7-03_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-03_activation[0][0]',
#                                 )                                 'block7-03_se_expand[0][0]']
#
#  block7-03_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-03_se_excite[0][0]']
#  )
#
#  block7-03_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-03_project_conv[0][0]']
#  malization)
#
#  block7-03_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-03_project_bn[0][0]']
#
#  block7-03_add (Add)            (None, 15, 15, 512)  0           ['block7-03_drop[0][0]',
#                                                                   'block7-02_add[0][0]']
#
#  block7-04_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-03_add[0][0]']
#                                 )
#
#  block7-04_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-04_expand_conv[0][0]']
#  alization)                     )
#
#  block7-04_expand_activation (A  (None, 15, 15, 3072  0          ['block7-04_expand_bn[0][0]']
#  ctivation)                     )
#
#  block7-04_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-04_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-04_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-04_dwconv2[0][0]']
#  on)                            )
#
#  block7-04_activation (Activati  (None, 15, 15, 3072  0          ['block7-04_bn[0][0]']
#  on)                            )
#
#  block7-04_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-04_activation[0][0]']
#  eragePooling2D)
#
#  block7-04_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-04_se_squeeze[0][0]']
#
#  block7-04_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-04_se_reshape[0][0]']
#
#  block7-04_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-04_se_reduce[0][0]']
#
#  block7-04_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-04_activation[0][0]',
#                                 )                                 'block7-04_se_expand[0][0]']
#
#  block7-04_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-04_se_excite[0][0]']
#  )
#
#  block7-04_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-04_project_conv[0][0]']
#  malization)
#
#  block7-04_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-04_project_bn[0][0]']
#
#  block7-04_add (Add)            (None, 15, 15, 512)  0           ['block7-04_drop[0][0]',
#                                                                   'block7-03_add[0][0]']
#
#  block7-05_expand_conv (Conv2D)  (None, 15, 15, 3072  1572864    ['block7-04_add[0][0]']
#                                 )
#
#  block7-05_expand_bn (BatchNorm  (None, 15, 15, 3072  12288      ['block7-05_expand_conv[0][0]']
#  alization)                     )
#
#  block7-05_expand_activation (A  (None, 15, 15, 3072  0          ['block7-05_expand_bn[0][0]']
#  ctivation)                     )
#
#  block7-05_dwconv2 (DepthwiseCo  (None, 15, 15, 3072  27648      ['block7-05_expand_activation[0][
#  nv2D)                          )                                0]']
#
#  block7-05_bn (BatchNormalizati  (None, 15, 15, 3072  12288      ['block7-05_dwconv2[0][0]']
#  on)                            )
#
#  block7-05_activation (Activati  (None, 15, 15, 3072  0          ['block7-05_bn[0][0]']
#  on)                            )
#
#  block7-05_se_squeeze (GlobalAv  (None, 3072)        0           ['block7-05_activation[0][0]']
#  eragePooling2D)
#
#  block7-05_se_reshape (Reshape)  (None, 1, 1, 3072)  0           ['block7-05_se_squeeze[0][0]']
#
#  block7-05_se_reduce (Conv2D)   (None, 1, 1, 128)    393344      ['block7-05_se_reshape[0][0]']
#
#  block7-05_se_expand (Conv2D)   (None, 1, 1, 3072)   396288      ['block7-05_se_reduce[0][0]']
#
#  block7-05_se_excite (Multiply)  (None, 15, 15, 3072  0          ['block7-05_activation[0][0]',
#                                 )                                 'block7-05_se_expand[0][0]']
#
#  block7-05_project_conv (Conv2D  (None, 15, 15, 512)  1572864    ['block7-05_se_excite[0][0]']
#  )
#
#  block7-05_project_bn (BatchNor  (None, 15, 15, 512)  2048       ['block7-05_project_conv[0][0]']
#  malization)
#
#  block7-05_drop (Dropout)       (None, 15, 15, 512)  0           ['block7-05_project_bn[0][0]']
#
#  block7-05_add (Add)            (None, 15, 15, 512)  0           ['block7-05_drop[0][0]',
#                                                                   'block7-04_add[0][0]']
#
#  top_conv (Conv2D)              (None, 15, 15, 1280  655360      ['block7-05_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 15, 15, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 15, 15, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  head_pooling (GlobalAveragePoo  (None, 1280)        0           ['top_activation[0][0]']
#  ling2D)
#
#  head_dropout (Dropout)         (None, 1280)         0           ['head_pooling[0][0]']
#
#  prediction_layer (Dense)       (None, 15)           19215       ['head_dropout[0][0]']
#
# ==================================================================================================
# Total params: 53,169,603
# Trainable params: 19,215
# Non-trainable params: 53,150,388
# __________________________________________________________________________________________________

# %%
## Create Data Loader
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255,
      validation_split=0.25,
      rotation_range=30,
      width_shift_range=0.2,
      height_shift_range=0.2,
      brightness_range=[0.5,1.5],
      shear_range=0.4,
      zoom_range=0.2,
      horizontal_flip=False,
      fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
        dataframe = trainframe,
        directory = None ,
        x_col = 'img_path',
        y_col = 'p',
        subset="training",
        target_size = (height, width),
        batch_size=BATCH_SIZE,
        color_mode= 'rgb',
        shuffle=True,
        class_mode='categorical')

valid_generator = train_datagen.flow_from_dataframe(
        dataframe = trainframe,
        directory = None ,
        x_col = 'img_path',
        y_col = 'p',
        subset="validation",
        target_size = (height, width),
        batch_size=BATCH_SIZE,
        color_mode= 'rgb',
        shuffle=True,
        class_mode='categorical')

test_generator = test_datagen.flow_from_dataframe(
        dataframe = testframe,
        directory = None,
        x_col = 'img_path',
        y_col = 'p',
        target_size = (height, width),
        batch_size=BATCH_SIZE,
        shuffle=False,
        color_mode= 'rgb',
        class_mode='categorical')
# Out:
# Found 263727 validated image filenames belonging to 15 classes.
# Found 87908 validated image filenames belonging to 15 classes.
# Found 46332 validated image filenames belonging to 13 classes.

# %% [markdown]
# ### 🗃️ Check Image

# %%
## Set TensorBoard 
root_logdir = '/media/SSD/Data_photogram_Pcar/EffnetV2Model/R1/Nfold-1/Mylogs_tensor/'  ##เปลี่ยน path 
if not os.path.exists(root_logdir) :
    os.makedirs(root_logdir)
    
def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d_%H_%M_%S")
    return os.path.join(root_logdir,run_id)
run_logdir = get_run_logdir()

tensorboard_cb = callbacks.TensorBoard(log_dir = run_logdir)

# %%
#Training model    
model.compile(
    optimizer= optimizers.Adam(learning_rate=0.00002),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


checkpoint_filepath = '/media/SSD/Data_photogram_Pcar/EffnetV2Model/R1/Nfold-1/checkpoint/' ### เปลี่ยน path
if not os.path.exists(checkpoint_filepath) :
        os.makedirs(checkpoint_filepath)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                                filepath=checkpoint_filepath, save_freq='epoch', ave_weights_only=False)

# %%
## Fit model 
model.fit(train_generator,
    epochs=3,
    validation_data=valid_generator,
    callbacks = [tensorboard_cb, model_checkpoint_callback])

# %%
##Save model as TFLiteConverter
modelName = 'EffnetV2m_R1_3DCAR15p_Nfold1'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

Pth_model_save = '/media/SSD/Data_photogram_Pcar/EffnetV2Model/R1/Nfold-1/models/'  ##เปลี่ยน path 
if not os.path.exists(Pth_model_save) :
    os.makedirs(Pth_model_save)

# Save model as .tflite
with open(f"{Pth_model_save}{modelName}.tflite", "wb") as file:
      file.write(tflite_model)
# Save model as .h5        
model.save(f'{Pth_model_save}{modelName}.h5') 
print(f'Save Model as [ {Pth_model_save}{{modelName}}.h5 ]')

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# ### Check Images extensions

# %%
import os
from PIL import Image
import cv2

folder_path = '/media/SSD/Data_photogram_Pcar/8-Fold'
extensions = []
# for fldr in os.listdir(folder_path):
#     sub_folder_path = os.path.join(folder_path, fldr)
#     print(sub_folder_path)
for filee in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filee)
    im = cv2.imread(file_path)
    #print('** Path: {}  **'.format(file_path), end="\r", flush=True)
    try:
        ih, iw, _ = im.shape
    except:
        extensions.append(file_path)
        print(file_path)
#     if image is None :
#         print(file_path)
        #extensions.append(file_path)
#     rgb_im = im.convert('RGB')
#     if filee.split('.')[1] not in extensions:
#         extensions.append(filee.split('.')[1])
# Out:
# libpng error: IDAT: CRC error
# libpng error: IDAT: incorrect data check

# %%
print(len(extensions))
extensions
# Out:
# 163862
# ['/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p15_dis1.8I2_angle0_elev110D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p4_dis1.8O3_angle317R2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p9_dis1.65I3_angle107_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p11_dis1.7I5_angle137R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p11_dis1.75_angle137R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p3_dis1.8O2_angle43R1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p13_dis1.85I1_angle180L3_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p8_dis1.75O1_angle320_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p10_dis1.65O2_angle253L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p11_dis1.75_angle137L4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p14_dis1.85O5_angle180L1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75_angle223L3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p13_dis1.95O2_angle180R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p13_dis1.95O1_angle180R1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75O2_angle40R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8I3_angle317L4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75I1_angle223L2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p9_dis1.65O4_angle107R2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p6_dis1.5I5_angle287R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75I5_angle40L4_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p6_dis1.5_angle287R3_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65I5_angle253L1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75_angle40L2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p3_dis1.8I2_angle43L1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p8_dis1.75I3_angle320R3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p3_dis1.8O4_angle43L4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95I1_angle180R1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p5_dis1.5I1_angle73L3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8O2_angle317L3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8I3_angle317L3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p14_dis1.85O3_angle180L4_elev25.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65O2_angle107L1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65I4_angle107R4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p14_dis1.85I1_angle180R2_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p15_dis1.8O2_angle0R2_elev110D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p4_dis1.8I3_angle317R3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p12_dis1.7I5_angle223L2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p7_dis1.8O4_angle40L1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8O5_angle0R2_elev110U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p11_dis1.7O2_angle137R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p15_dis1.8O4_angle0L2_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p2_dis1.9O3_angle0R1_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p15_dis1.8O5_angle0_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85_angle180L3_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8O5_angle320_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p2_dis1.9I5_angle0R3_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p14_dis1.95I3_angle180_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p7_dis1.75O3_angle40L1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8_angle317L4_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p2_dis1.9I5_angle0L4_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5I2_angle287L2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p1_dis1.85O1_angle0L3_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65O5_angle253L4_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95I4_angle180R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7O2_angle223R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8I4_angle0_elev110D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p7_dis1.8I2_angle40_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75O4_angle223L3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8O2_angle43R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p9_dis1.65O2_angle107L2_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p6_dis1.5I4_angle287R1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8I1_angle317R2_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p2_dis1.9O2_angle0L4_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p3_dis1.8O2_angle43L4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p5_dis1.5O1_angle73L1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65I2_angle107R1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p13_dis1.85I1_angle180R4_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p8_dis1.8_angle320R4_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p15_dis1.8O3_angle0R2_elev110D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p11_dis1.75I4_angle137R2_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p8_dis1.75I3_angle320R2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p14_dis1.8I3_angle180R2_elev20D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p15_dis1.8O1_angle0R3_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7O5_angle223L3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95O5_angle0R1_elev8U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p8_dis1.75O5_angle320L1_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p14_dis1.8O3_angle180L3_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p13_dis1.85O2_angle180R4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5O4_angle287R3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8O3_angle0R2_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p14_dis1.85O1_angle180L2_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p15_dis1.8O1_angle0L3_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p3_dis1.8I5_angle43_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p7_dis1.8O3_angle40L4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p6_dis1.5I4_angle287L1_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p12_dis1.75O2_angle223L3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8O3_angle0_elev110U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p6_dis1.5_angle287R1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p15_dis1.8O2_angle0R1_elev110D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p14_dis1.95I1_angle180L3_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p9_dis1.65O5_angle107R2_elev35D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p8_dis1.75O5_angle320_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5I4_angle287R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p12_dis1.75O5_angle223R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p4_dis1.8I1_angle317_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p12_dis1.75O4_angle223R4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8I3_angle180R4_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p6_dis1.5O1_angle287L4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p8_dis1.8O1_angle320L2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p15_dis1.8O1_angle0R2_elev110U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8I2_angle0R2_elev110D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p11_dis1.75I4_angle137R3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75O3_angle223R3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p3_dis1.8O1_angle43L3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p14_dis1.85O1_angle180L1_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75O1_angle40R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p4_dis1.8O3_angle317L2_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5O3_angle287L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8O4_angle317R2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p6_dis1.5_angle287R4_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p7_dis1.75O4_angle40R4_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8I5_angle320L3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75I1_angle137R3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p13_dis1.8_angle180_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p13_dis1.85_angle180L4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p12_dis1.7I2_angle223L2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p12_dis1.7I5_angle223R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p14_dis1.85I3_angle180_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p5_dis1.5O5_angle73R3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p14_dis1.95I1_angle180R4_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p13_dis1.8I3_angle180R4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p8_dis1.8O1_angle320R1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p3_dis1.8I2_angle43R1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p6_dis1.5I3_angle287R3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p6_dis1.5I1_angle287R4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p13_dis1.8O5_angle180R2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p6_dis1.5O2_angle287L2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p3_dis1.8O5_angle43L3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p12_dis1.75O1_angle223R3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5I5_angle287R1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p2_dis1.9O5_angle0R4_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65O3_angle253R3_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8I3_angle0L3_elev110D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p12_dis1.75O3_angle223R4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p1_dis1.85I1_angle0R4_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65O3_angle107R4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p13_dis1.85I1_angle180L2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p14_dis1.85I3_angle180R4_elev25D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p13_dis1.8I5_angle180L3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p5_dis1.5O3_angle73R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p7_dis1.8O1_angle40_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p3_dis1.8O5_angle43L4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p3_dis1.8I5_angle43L4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p7_dis1.75_angle40L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9I5_angle0L3_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5I3_angle73L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p1_dis1.85I2_angle0R3_elev8U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p15_dis1.8O4_angle0L1_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p2_dis1.95I2_angle0_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8O1_angle43R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p11_dis1.7O1_angle137R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p5_dis1.5O3_angle73L2_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p13_dis1.85I5_angle180L4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9I4_angle0_elev8D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p11_dis1.7I4_angle137L3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p9_dis1.65I4_angle107L2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65I4_angle253R4_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p13_dis1.8O5_angle180R4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p6_dis1.5I1_angle287L2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65I2_angle253R3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p4_dis1.8I3_angle317R2_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p5_dis1.5I2_angle73_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p13_dis1.95O5_angle180R1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p11_dis1.75O2_angle137R2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p8_dis1.8I3_angle320L1_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p9_dis1.65I5_angle107R1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p3_dis1.8O5_angle43L1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p11_dis1.75O5_angle137R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p3_dis1.8O5_angle43R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p6_dis1.5I3_angle287R3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95O1_angle180L3_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p15_dis1.8O4_angle0L1_elev110D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5_angle73L2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75I3_angle40_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p5_dis1.5I1_angle73R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p13_dis1.85O5_angle180R3_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p5_dis1.5O2_angle73R2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p12_dis1.75I3_angle223R4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O4_angle180L2_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p8_dis1.75I1_angle320L2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p6_dis1.5I3_angle287R2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p1_dis1.85I2_angle0L1_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p9_dis1.65O2_angle107L4_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p6_dis1.5O5_angle287_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p6_dis1.5O2_angle287R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75_angle40R1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p3_dis1.8I5_angle43R3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8O1_angle43L2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75I5_angle40R3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8O1_angle320L3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p4_dis1.8O3_angle317L2_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5I1_angle73R1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p3_dis1.8O3_angle43R3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p9_dis1.65O3_angle107L3_elev35.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75I5_angle137L1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p12_dis1.75I1_angle223R4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75O4_angle137R1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p9_dis1.65O3_angle107L4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p2_dis1.95O5_angle0R4_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p14_dis1.95O5_angle180L2_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p11_dis1.7I3_angle137R3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p4_dis1.8O3_angle317R3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8I3_angle0L4_elev110D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65_angle107R2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p5_dis1.5O5_angle73R2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p6_dis1.5I5_angle287L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8O2_angle317L2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p12_dis1.7I2_angle223L1_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75I1_angle137L4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p3_dis1.8_angle43_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p4_dis1.8I3_angle317L4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p1_dis1.9O1_angle0R4_elev8U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8I4_angle0L3_elev110D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p9_dis1.65O1_angle107L2_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p1_dis1.85O3_angle0L4_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p5_dis1.5O5_angle73L3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p11_dis1.7I4_angle137L2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p11_dis1.75_angle137R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5O2_angle73L1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p4_dis1.8O4_angle317L4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p1_dis1.95I4_angle0R2_elev8U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p7_dis1.75O1_angle40L4_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65_angle253R3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8I5_angle317R1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O5_angle73L4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p3_dis1.8O4_angle43R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O4_angle287_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p9_dis1.65I3_angle107R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p2_dis1.9O4_angle0R3_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p14_dis1.8O3_angle180R4_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p13_dis1.8I4_angle180R3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p14_dis1.95I1_angle180L1_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p8_dis1.75I4_angle320R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p5_dis1.5I2_angle73R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95I3_angle180L1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p5_dis1.5I4_angle73L1_elev35D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p5_dis1.5I3_angle73_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65I3_angle253R3_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p6_dis1.5O4_angle287R1_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p4_dis1.8O4_angle317L2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75O5_angle223R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p8_dis1.75O5_angle320R4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p1_dis1.9I1_angle0L4_elev8D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p5_dis1.5O1_angle73L3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p3_dis1.8O2_angle43_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p10_dis1.65O2_angle253R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p11_dis1.75I4_angle137L3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p7_dis1.75I4_angle40R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p2_dis1.85I1_angle0L3_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p15_dis1.8O2_angle0R1_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p11_dis1.75_angle137R2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p12_dis1.75I2_angle223L2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p2_dis1.85O5_angle0L2_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p12_dis1.7I3_angle223R1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p1_dis1.85O3_angle0_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p8_dis1.75O5_angle320R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75I4_angle40R2_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p6_dis1.5O5_angle287L4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O2_angle180L4_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p4_dis1.8I1_angle317_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p10_dis1.65O5_angle253R1_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75I1_angle137L3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p11_dis1.75I5_angle137L1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p5_dis1.5O2_angle73L3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p2_dis1.9I3_angle0R1_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p14_dis1.8I1_angle180L4_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p12_dis1.7I1_angle223L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p2_dis1.9_angle0R1_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O3_angle73R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8O2_angle317L2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p7_dis1.75I3_angle40R3_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8I4_angle0R4_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8O5_angle317L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p3_dis1.8O5_angle43L1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p4_dis1.8_angle317R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p5_dis1.5O4_angle73R4_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p11_dis1.75_angle137L2_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p14_dis1.95_angle180R1_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p14_dis1.8I2_angle180R1_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p15_dis1.8O4_angle0R2_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p8_dis1.75O1_angle320L4_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p11_dis1.75O4_angle137_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8O5_angle317R1_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65O1_angle107R2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75O1_angle40R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p15_dis1.8I2_angle0L2_elev110D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5O3_angle73R1_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p2_dis1.9I3_angle0R2_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p6_dis1.5O1_angle287_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p8_dis1.75O5_angle320_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5O2_angle73L4_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8I2_angle43R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p15_dis1.8I3_angle0L1_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5O1_angle73R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p13_dis1.8I4_angle180R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p2_dis1.9I2_angle0R1_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p6_dis1.5I4_angle287R2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p6_dis1.5I5_angle287R1_elev35.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p15_dis1.8O3_angle0R4_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p2_dis1.95I5_angle0L2_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p7_dis1.75_angle40L3_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p15_dis1.8O5_angle0L3_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8O3_angle317L1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p12_dis1.75O4_angle223L3_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p15_dis1.8I2_angle0_elev110D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p13_dis1.85_angle180L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p1_dis1.85I5_angle0R3_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p13_dis1.95I2_angle180R1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p11_dis1.7O5_angle137R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p6_dis1.5O2_angle287R3_elev35D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p7_dis1.75I3_angle40L3_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p8_dis1.75I2_angle320L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p12_dis1.75I1_angle223R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p15_dis1.8O3_angle0L1_elev110U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p2_dis1.9O3_angle0L1_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p10_dis1.65I2_angle253R3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65O2_angle253R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p2_dis1.85O5_angle0L4_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p2_dis1.85_angle0R2_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p7_dis1.8I2_angle40L3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8O2_angle317R2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p10_dis1.65O1_angle253R2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p1_dis1.95_angle0L3_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p4_dis1.8I5_angle317L2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p11_dis1.75O3_angle137R1_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p7_dis1.75I4_angle40L3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p2_dis1.95O2_angle0R1_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8O2_angle0R2_elev110U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p7_dis1.8O2_angle40L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p1_dis1.9I1_angle0L1_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O2_angle180L4_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8_angle320L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5I4_angle287L4_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7O5_angle223R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p7_dis1.8I3_angle40R4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75O2_angle40L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p13_dis1.85_angle180L1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5O3_angle287R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p11_dis1.75O5_angle137L2_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p14_dis1.8O3_angle180R2_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p13_dis1.8O2_angle180R4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8O3_angle317R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O2_angle287L4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p5_dis1.5_angle73_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p2_dis1.95I2_angle0R1_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p2_dis1.85I5_angle0L4_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p15_dis1.8O5_angle0L3_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O3_angle73_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8I5_angle317L3_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p11_dis1.75O1_angle137L3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75O2_angle223R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p12_dis1.75I2_angle223L3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p15_dis1.8I1_angle0_elev110U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p2_dis1.9O4_angle0R3_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p13_dis1.8O3_angle180L1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p15_dis1.8I5_angle0_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p10_dis1.65O5_angle253R3_elev35U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p7_dis1.75I1_angle40R3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p3_dis1.8_angle43R1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p10_dis1.65I2_angle253R2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O2_angle180R4_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65O2_angle253_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p9_dis1.65I5_angle107L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p7_dis1.8O2_angle40R1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O2_angle73R3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p9_dis1.65I2_angle107_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p10_dis1.65I3_angle253R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p2_dis1.95O2_angle0R3_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65I2_angle107L3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8O2_angle43L4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p4_dis1.8O3_angle317R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p12_dis1.75O2_angle223L4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5O3_angle73L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p12_dis1.7I5_angle223L1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p13_dis1.8I4_angle180R4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p14_dis1.85_angle180L1_elev20D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p4_dis1.8O4_angle317L4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5_angle287R3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95O4_angle180R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p5_dis1.5I5_angle73L2_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65I3_angle107R4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9_angle0_elev8U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5_angle287L4_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p9_dis1.65O2_angle107R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p13_dis1.95O2_angle180L4_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5O5_angle287R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p3_dis1.8O2_angle43R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95I4_angle0R4_elev8D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p14_dis1.95O1_angle180R3_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p12_dis1.75O1_angle223R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p6_dis1.5O4_angle287R2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p5_dis1.5I5_angle73L1_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p11_dis1.7_angle137L2_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p3_dis1.8O2_angle43_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75I4_angle40R3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p8_dis1.8I2_angle320L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p2_dis1.95I5_angle0R1_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75I1_angle137R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p10_dis1.65I1_angle253R3_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95I3_angle180R2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8_angle43R1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p14_dis1.95I4_angle180L4_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75I1_angle40R2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p6_dis1.5I1_angle287R4_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p4_dis1.8I4_angle317_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p1_dis1.95I2_angle0_elev8U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p9_dis1.65I4_angle107L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p11_dis1.75O1_angle137L1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p14_dis1.8_angle180R1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65O1_angle107R3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8O3_angle320R1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p5_dis1.5I4_angle73L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p2_dis1.9I1_angle0R3_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p15_dis1.8O2_angle0L1_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65O1_angle253L3_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p13_dis1.8I1_angle180_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8O5_angle317R4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p9_dis1.65I2_angle107L3_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p7_dis1.75I4_angle40R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p15_dis1.8O3_angle0R2_elev110D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p13_dis1.85I3_angle180R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p12_dis1.75O5_angle223L1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p12_dis1.75O1_angle223R3_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5I5_angle73L4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5I4_angle287R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p7_dis1.75I2_angle40R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p15_dis1.8I3_angle0R3_elev110D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p8_dis1.75O3_angle320L3_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p11_dis1.75O4_angle137R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p4_dis1.8O4_angle317L3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p3_dis1.8O4_angle43_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p4_dis1.8O5_angle317_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75O5_angle223R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p5_dis1.5O1_angle73R2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p4_dis1.8I2_angle317R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5_angle287_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p11_dis1.7O2_angle137R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p14_dis1.8I2_angle180R2_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p10_dis1.65O4_angle253L1_elev35D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p8_dis1.75_angle320L4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p6_dis1.5_angle287_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p4_dis1.8O2_angle317_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p1_dis1.95O1_angle0L3_elev8D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p11_dis1.75_angle137R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p11_dis1.75I3_angle137R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p9_dis1.65I5_angle107L2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p4_dis1.8_angle317R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p13_dis1.95I3_angle180R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p2_dis1.85O5_angle0L4_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p3_dis1.8O1_angle43L1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p2_dis1.95O2_angle0L3_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9O3_angle0L3_elev8U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9I5_angle0R1_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p15_dis1.8O4_angle0L1_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75O2_angle137L2_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p12_dis1.75I3_angle223_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p8_dis1.75I4_angle320L4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p11_dis1.75O1_angle137_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8_angle320R3_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p13_dis1.85I5_angle180R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p11_dis1.7O3_angle137R1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5O2_angle287R4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p1_dis1.9I3_angle0L4_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5I1_angle73L1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p6_dis1.5O5_angle287L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p6_dis1.5O4_angle287R3_elev35.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p9_dis1.65O2_angle107L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p2_dis1.85O3_angle0L3_elev20D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p13_dis1.85I1_angle180R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p5_dis1.5O2_angle73L2_elev35.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p3_dis1.8I3_angle43R3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p2_dis1.85O3_angle0_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75_angle223R3_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p1_dis1.85O4_angle0R3_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5I4_angle287L2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p5_dis1.5O3_angle73L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p3_dis1.8I3_angle43R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65I3_angle253L2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p7_dis1.8O1_angle40L3_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p3_dis1.8O1_angle43R3_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p8_dis1.8I4_angle320R1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p1_dis1.95O2_angle0L1_elev8U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O4_angle180R3_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8I3_angle0R1_elev110D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p3_dis1.8I1_angle43L2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95I1_angle0_elev8D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p4_dis1.8I1_angle317L2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p8_dis1.75O3_angle320_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8O2_angle317L4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p15_dis1.8I5_angle0L2_elev110D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p13_dis1.95O4_angle180R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O3_angle73L4_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p3_dis1.8I2_angle43R3_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8O3_angle317L1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p5_dis1.5I3_angle73R3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p7_dis1.8I3_angle40R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p7_dis1.75O1_angle40R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p2_dis1.9O3_angle0L3_elev20D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p3_dis1.8I5_angle43R3_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p5_dis1.5O1_angle73L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p4_dis1.8_angle317R4_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p14_dis1.85O2_angle180R3_elev25D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p12_dis1.75_angle223L3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65O3_angle253R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65_angle107R1_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p7_dis1.8O3_angle40_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8I2_angle317R2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p2_dis1.95O4_angle0L2_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p13_dis1.95I5_angle180R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p7_dis1.75I3_angle40_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p3_dis1.8O5_angle43R1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7_angle223R3_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75O1_angle223R3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p10_dis1.65O4_angle253R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p7_dis1.75I1_angle40R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p5_dis1.5I2_angle73R4_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p13_dis1.95O1_angle180L3_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p6_dis1.5_angle287L3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p10_dis1.65O3_angle253R1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p9_dis1.65I2_angle107R4_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p11_dis1.75I4_angle137L2_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p12_dis1.7_angle223L4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O1_angle180_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65O5_angle107R4_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p3_dis1.8O4_angle43L2_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O4_angle180L1_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p10_dis1.65I5_angle253L2_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9O2_angle0_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p8_dis1.75I1_angle320L2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p13_dis1.8I1_angle180L4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75I2_angle40_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8I2_angle320L3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75O2_angle223R2_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p8_dis1.75O2_angle320_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8O5_angle0L2_elev110D1.png',
# ...
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p3_dis1.8I5_angle43R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p9_dis1.65I4_angle107R3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p10_dis1.65O4_angle253L3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p14_dis1.8I4_angle180R3_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75I1_angle40L1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p4_dis1.8O3_angle317R3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p14_dis1.85O5_angle180R1_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p9_dis1.65I5_angle107L3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O4_angle180R4_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p7_dis1.75I4_angle40L4_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p11_dis1.75O2_angle137R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5_angle73L1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8I5_angle320R4_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p4_dis1.8I1_angle317L3_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5_angle287R2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p11_dis1.75O1_angle137R1_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9O4_angle0L1_elev8D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7I1_angle223R4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p11_dis1.7_angle137L1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p13_dis1.85O3_angle180R2_elev15U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p12_dis1.7I5_angle223R3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p7_dis1.75I1_angle40L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5I2_angle73L3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p1_dis1.95I2_angle0L4_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75I5_angle40L2_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75I4_angle40_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p3_dis1.8I5_angle43R4_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p1_dis1.9I2_angle0L1_elev8U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5O2_angle287R1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p2_dis1.85O2_angle0_elev20D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p12_dis1.75O2_angle223R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p6_dis1.5O3_angle287L1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p11_dis1.75I2_angle137R4_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p9_dis1.65I3_angle107R2_elev35U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p7_dis1.75I5_angle40R1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p7_dis1.8O3_angle40L3_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p15_dis1.8O1_angle0R3_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p12_dis1.75I1_angle223L3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p11_dis1.75O5_angle137L3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p12_dis1.75O3_angle223L3_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p12_dis1.75O4_angle223L4_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p9_dis1.65_angle107R1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p1_dis1.9I5_angle0L3_elev8D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p9_dis1.65O4_angle107R4_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p6_dis1.5O2_angle287L1_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p12_dis1.75O2_angle223_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p5_dis1.5_angle73L2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p8_dis1.75O4_angle320R1_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p6_dis1.5I3_angle287L2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p2_dis1.95I3_angle0R2_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5I5_angle73R2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p11_dis1.75O2_angle137R3_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p7_dis1.8I4_angle40R2_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p13_dis1.85I4_angle180L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p11_dis1.75O4_angle137R4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p11_dis1.7O1_angle137_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p6_dis1.5_angle287R4_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p12_dis1.7_angle223L4_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p1_dis1.95O2_angle0L2_elev8D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75I1_angle40L1_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75O1_angle40R2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p15_dis1.8I3_angle0R1_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p5_dis1.5_angle73_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p7_dis1.8_angle40L2_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p9_dis1.65I1_angle107L1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p15_dis1.8O4_angle0R2_elev110U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p11_dis1.75O3_angle137R1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p13_dis1.95O4_angle180R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p12_dis1.7_angle223L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p8_dis1.8O3_angle320R2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p5_dis1.5I5_angle73R3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p4_dis1.8O5_angle317R1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p10_dis1.65O5_angle253R2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5I5_angle73R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p5_dis1.5I2_angle73L3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5O4_angle287R4_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p6_dis1.5I1_angle287L4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75I3_angle223L3_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p13_dis1.95O5_angle180R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p4_dis1.8_angle317L2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p5_dis1.5O2_angle73L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p2_dis1.95O2_angle0L2_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p5_dis1.5O1_angle73L2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p15_dis1.8O2_angle0R1_elev110D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p13_dis1.8I3_angle180L1_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p15_dis1.8_angle0L1_elev110D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p1_dis1.85I2_angle0L1_elev8U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p15_dis1.8_angle0R2_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p1_dis1.9O5_angle0R4_elev8D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p14_dis1.85I4_angle180R1_elev25U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p10_dis1.65O1_angle253L4_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p7_dis1.75I1_angle40L2_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p1_dis1.95O5_angle0L1_elev8D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O2_angle180_elev20D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p3_dis1.8O1_angle43_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p5_dis1.5I1_angle73L3_elev35.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p11_dis1.7I4_angle137R2_elev15U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p9_dis1.65I2_angle107L1_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p12_dis1.75I5_angle223R3_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p14_dis1.8O5_angle180L1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5I3_angle287L3_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p15_dis1.8I5_angle0L1_elev110U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95O5_angle0L1_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p7_dis1.75_angle40_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5I3_angle73L4_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p15_dis1.8O1_angle0_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p7_dis1.75I3_angle40R4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p2_dis1.9I1_angle0R1_elev20U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5O1_angle287L1_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p4_dis1.8_angle317R4_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p15_dis1.8O2_angle0R4_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p11_dis1.75O3_angle137R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p1_dis1.85I1_angle0_elev8D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O5_angle180R2_elev20U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p5_dis1.5I3_angle73L3_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p5_dis1.5I5_angle73L3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p6_dis1.5O3_angle287L1_elev35U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p12_dis1.75I3_angle223R2_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p6_dis1.5_angle287R3_elev30D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p13_dis1.8O2_angle180L3_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p8_dis1.75O4_angle320R4_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95I2_angle0L2_elev8D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p1_dis1.95I4_angle0R4_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p13_dis1.85O4_angle180L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p12_dis1.7I3_angle223R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7I4_angle223_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p13_dis1.95O3_angle180L4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p6_dis1.5I5_angle287R3_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p1_dis1.85O1_angle0_elev8U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5I4_angle287R2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p9_dis1.65_angle107L2_elev30D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p13_dis1.8I1_angle180R3_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p13_dis1.85I4_angle180_elev15U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8O5_angle317L1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p10_dis1.65O5_angle253R4_elev35U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p1_dis1.85O5_angle0R3_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p10_dis1.65I5_angle253R1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p5_dis1.5_angle73R1_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p15_dis1.8I3_angle0_elev110U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p4_dis1.8O4_angle317R1_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p1_dis1.95O3_angle0L2_elev8D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p5_dis1.5O2_angle73R1_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p12_dis1.75_angle223R2_elev15D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p8_dis1.75O4_angle320R2_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p4_dis1.8I2_angle317R2_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p11_dis1.7I2_angle137R1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p3_dis1.8I1_angle43R2_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p13_dis1.95I3_angle180_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p5_dis1.5O2_angle73_elev30U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p13_dis1.85O2_angle180R4_elev15D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8O5_angle320L3_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p11_dis1.7O4_angle137L1_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p9_dis1.65O4_angle107R3_elev35U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p1_dis1.9I2_angle0L2_elev8U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p2_dis1.85O3_angle0L1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Base_p12_dis1.7O1_angle223R1_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p14_dis1.95O1_angle180R4_elev20U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8I1_angle180R1_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p1_dis1.9O1_angle0R3_elev8.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p5_dis1.5I2_angle73R4_elev30U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p6_dis1.5O1_angle287L1_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p14_dis1.85I4_angle180R1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p15_dis1.8_angle0_elev110.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Base_p12_dis1.75O4_angle223R1_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Minor_p14_dis1.8O4_angle180R4_elev20U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Severe_p1_dis1.9O1_angle0L1_elev8U1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id13-Moderate_p5_dis1.5I1_angle73L2_elev30D3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Base_p13_dis1.95_angle180R3_elev15.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p8_dis1.75O5_angle320R2_elev30U3.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p3_dis1.8I2_angle43L4_elev15U4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p3_dis1.8I1_angle43L4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Severe_p4_dis1.8I3_angle317R4_elev15D2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id12-Severe_p5_dis1.5I3_angle73L1_elev35U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p4_dis1.8O2_angle317L1_elev15D1.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p8_dis1.8O2_angle320_elev30U2.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Severe_p14_dis1.85O1_angle180R1_elev20.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Moderate_p6_dis1.5_angle287R4_elev30D4.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p6_dis1.5I2_angle287_elev30.png',
#  '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Minor_p2_dis1.85O3_angle0R4_elev20D2.png',
#  ...]

# %%
img_extensions = pd.DataFrame(extensions, columns =['path_train'])
print(img_extensions.shape)
img_extensions.head()
# Out:
# (163862, 1)
#                                           path_train
# 0  /media/SSD/Data_photogram_Pcar/8-Fold/id26-Mod...
# 1  /media/SSD/Data_photogram_Pcar/8-Fold/id14-Bas...
# 2  /media/SSD/Data_photogram_Pcar/8-Fold/id26-Mod...
# 3  /media/SSD/Data_photogram_Pcar/8-Fold/id14-Bas...
# 4  /media/SSD/Data_photogram_Pcar/8-Fold/id13-Min...

# %%
with open(f'{f_name_toSave}/{txt_name}-demo.txt', 'w') as f:
         for line in list_path:
             f.write(f"{line}\n")

# %%
img_extensions.to_csv('/media/SSD/Data_photogram_Pcar/3DCar_img_extensions.csv')

# %% [markdown]
# ### ย้าย image ใหม่

# %%
# columns = list(database.columns)
# df0_ = pd.DataFrame(columns=columns)
df0_ = []
extensions_ = img_extensions['path_train'].tolist()
for p in extensions_:
    df0 = database[database['path_train'] == p]
    #df0_ = df0_.append(df0)
    df0_.append(df0)

## Concat df     
df_all = pd.concat(df0_)
print(df_all.shape)
df_all.head()

# %%
df0_
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, ID, Damage, p, FileName, distance, Angle, img_path, Fold, path_train]
# Index: []

# %%
import shutil as sh
import time

path2save = '/media/SSD/Data_photogram_Pcar/8-Fold/'
fold0 = list(set(Table_path_['Fold']))
fold0.sort()
for i in range(len(fold0)):
    df0 = Table_path_[Table_path_['Fold'] == fold0[i]]
    path_img = df0['img_path'].tolist()
    name_img = df0['FileName'].tolist()
    if not os.path.exists('{}'.format(path2save)) :
             os.makedirs('{}'.format(path2save))
    for j in range(len(path_img)):
        sh.copy("{}".format(path_img[j]),"{}{}".format(path2save, name_img[j]))
    print(f'On process Copy at fold -->> [ {fold0[i]} ] ')
    print('-'*100)
    time.sleep(5)

# %%
#file_path

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os
import random

# ims = random.choices(file, k=5)
# for im in ims:
#     #print(im)
#     name_im = im.split('/')[-1]
#     #print(name_im)
im = '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png'
name_im = im.split('/')[-1]
image = cv2.imread(im)
if image == None :
    print(f'Image Cannot Open')
# sZ = os.path.getsize(im)
# #print(f"Images Name : **{name_im}, --> Shape ", image.shape)
# print(f"image size: {sZ:,} bytes")
# plt.axis("off")
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.show()
# Out:
# Image Cannot Open

# %%
im0 = database[database['path_train'] == '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png']
im0
# Out:
#         Unnamed: 0.1  Unnamed: 0    ID    Damage   p  \
# 281829        281829      281829  id26  Moderate  p6
#
#                                                  FileName  distance  \
# 281829  id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png  dis1.5O2
#
#              Angle                                           img_path    Fold  \
# 281829  Angle287L1  /media/SSD/Data_photogram_car/id26/Moderate/p6...  fold-8
#
#                                                path_train
# 281829  /media/SSD/Data_photogram_Pcar/8-Fold/id26-Mod...

# %%
im0['img_path'].tolist()
# Out:
# ['/media/SSD/Data_photogram_car/id26/Moderate/p6/dis1.5O2/Angle287L1/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png']

# %%
#im = '/media/SSD/Data_photogram_car/id26/Moderate/p6/dis1.5O2/Angle287L1/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png'
im = '/media/SSD/Data_photogram_Pcar/8-Fold/id14-Minor_p6_dis1.5I2_angle287_elev30.png'
name_im = im.split('/')[-1]
image = cv2.imread(im)
#image
if image is None :
    print(f'Image Cannot Open')
else:
    sZ = os.path.getsize(im)
    print(f"Images Name : **{name_im}, --> Shape ", image.shape)
    print(f"image size: {sZ:,} bytes")
    plt.axis("off")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Image Cannot Open

# %%
image

# %%
os.listdir(folder_path)
# Out:
# ['id6-Base_p13_dis1.95O3_angle180L1_elev15D1.png',
#  'id2-Moderate_p11_dis1.7I2_angle137_elev15.png',
#  'id6-Base_p4_dis1.8I3_angle317R1_elev15.png',
#  'id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png',
#  'id14-Base_p15_dis1.8I2_angle0_elev110D2.png',
#  'id12-Moderate_p13_dis1.85O4_angle180L3_elev15D3.png',
#  'id2-Moderate_p2_dis1.8I1_angle0L1_elev20.png',
#  'id2-Minor_p2_dis1.8O1_angle0R4_elev20D3.png',
#  'id26-Moderate_p4_dis1.8O3_angle317R2_elev15U3.png',
#  'id14-Base_p9_dis1.65I3_angle107_elev30.png',
#  'id13-Minor_p11_dis1.7I5_angle137R3_elev15U4.png',
#  'id26-Minor_p11_dis1.75_angle137R2_elev15.png',
#  'id8-Moderate_p11_dis1.75_angle137L3_elev15U4.png',
#  'id13-Severe_p3_dis1.8O2_angle43R1_elev15U1.png',
#  'id26-Minor_p13_dis1.85I1_angle180L3_elev15D4.png',
#  'id12-Moderate_p8_dis1.75I3_angle320R1_elev30D4.png',
#  'id26-Severe_p8_dis1.75O1_angle320_elev30D3.png',
#  'id6-Moderate_p6_dis1.5O2_angle287L3_elev30D1.png',
#  'id2-Moderate_p12_dis1.7O3_angle223_elev15U3.png',
#  'id2-Severe_p7_dis1.7I4_angle40_elev30D1.png',
#  'id6-Base_p14_dis1.95O4_angle180L1_elev20U4.png',
#  'id6-Minor_p3_dis1.8I5_angle43L4_elev15D1.png',
#  'id26-Minor_p10_dis1.65O2_angle253L1_elev30.png',
#  'id14-Moderate_p11_dis1.75_angle137L4_elev15D3.png',
#  'id12-Moderate_p8_dis1.75I1_angle320L4_elev30.png',
#  'id26-Base_p14_dis1.85O5_angle180L1_elev20.png',
#  'id2-Base_p2_dis1.8I4_angle0L2_elev20D1.png',
#  'id10-Moderate_p11_dis1.75I1_angle137R2_elev15D4.png',
#  'id14-Minor_p12_dis1.75_angle223L3_elev15U4.png',
#  'id14-Minor_p13_dis1.95O2_angle180R2_elev15.png',
#  'id14-Minor_p13_dis1.95O1_angle180R1_elev15D2.png',
#  'id13-Base_p7_dis1.75O2_angle40R2_elev30U4.png',
#  'id14-Moderate_p4_dis1.8I3_angle317L4_elev15D4.png',
#  'id14-Minor_p12_dis1.75I1_angle223L2_elev15U2.png',
#  'id14-Minor_p9_dis1.65O4_angle107R2_elev30D2.png',
#  'id14-Base_p6_dis1.5I5_angle287R1_elev30.png',
#  'id8-Moderate_p8_dis1.75I4_angle320R1_elev30.png',
#  'id26-Base_p7_dis1.75I5_angle40L4_elev30D2.png',
#  'id8-Minor_p2_dis1.85I4_angle0R2_elev20U3.png',
#  'id6-Minor_p5_dis1.5O1_angle73R2_elev30U1.png',
#  'id10-Minor_p15_dis1.8O1_angle0R2_elev110U3.png',
#  'id8-Severe_p4_dis1.8_angle317_elev15D2.png',
#  'id14-Minor_p6_dis1.5_angle287R3_elev30D3.png',
#  'id26-Moderate_p10_dis1.65I5_angle253L1_elev30U2.png',
#  'id26-Base_p7_dis1.75_angle40L2_elev30U1.png',
#  'id13-Minor_p3_dis1.8I2_angle43L1_elev15.png',
#  'id10-Base_p2_dis1.9_angle0R1_elev20D3.png',
#  'id12-Minor_p11_dis1.75I5_angle137_elev15D3.png',
#  'id6-Severe_p3_dis1.8I3_angle43R1_elev15U2.png',
#  'id6-Severe_p5_dis1.5I1_angle73R4_elev30.png',
#  'id8-Base_p5_dis1.5I3_angle73L2_elev30D3.png',
#  'id12-Moderate_p13_dis1.85O4_angle180R3_elev15U1.png',
#  'id10-Severe_p12_dis1.75I2_angle223L2_elev15D2.png',
#  'id12-Base_p3_dis1.8O3_angle43L4_elev15D3.png',
#  'id13-Moderate_p8_dis1.75I3_angle320R3_elev30D2.png',
#  'id26-Moderate_p3_dis1.8O4_angle43L4_elev15.png',
#  'id2-Moderate_p7_dis1.7O5_angle40_elev30D2.png',
#  'id2-Moderate_p1_dis1.8I5_angle0L2_elev8D1.png',
#  'id14-Moderate_p13_dis1.95I1_angle180R1_elev15.png',
#  'id14-Moderate_p5_dis1.5I1_angle73L3_elev30U3.png',
#  'id2-Base_p14_dis1.8O5_angle180L3_elev20U3.png',
#  'id14-Base_p4_dis1.8O2_angle317L3_elev15D2.png',
#  'id8-Severe_p8_dis1.75O5_angle320_elev30U3.png',
#  'id8-Moderate_p5_dis1.5O2_angle73L2_elev30U1.png',
#  'id8-Moderate_p5_dis1.5I3_angle73L1_elev30D2.png',
#  'id10-Severe_p5_dis1.5I4_angle73R1_elev30U3.png',
#  'id8-Minor_p8_dis1.75I5_angle320R1_elev30.png',
#  'id8-Severe_p8_dis1.75O2_angle320R3_elev30D1.png',
#  'id6-Moderate_p12_dis1.75I3_angle223L1_elev15D2.png',
#  'id13-Base_p4_dis1.8I3_angle317L3_elev15D2.png',
#  'id6-Moderate_p14_dis1.95O5_angle180L2_elev20D2.png',
#  'id12-Minor_p1_dis1.85I4_angle0_elev8D2.png',
#  'id10-Severe_p2_dis1.9I5_angle0R3_elev20D1.png',
#  'id8-Severe_p13_dis1.85I5_angle180R4_elev15U3.png',
#  'id12-Severe_p14_dis1.85O3_angle180L4_elev25.png',
#  'id26-Severe_p9_dis1.65O2_angle107L1_elev30D3.png',
#  'id26-Severe_p9_dis1.65I4_angle107R4_elev30U3.png',
#  'id26-Moderate_p14_dis1.85I1_angle180R2_elev20.png',
#  'id12-Severe_p15_dis1.8O2_angle0R2_elev110D4.png',
#  'id8-Moderate_p13_dis1.85I3_angle180L1_elev15.png',
#  'id26-Severe_p4_dis1.8I3_angle317R3_elev15U2.png',
#  'id6-Minor_p12_dis1.75O5_angle223_elev15.png',
#  'id13-Severe_p12_dis1.7I5_angle223L2_elev15.png',
#  'id14-Severe_p7_dis1.8O4_angle40L1_elev30U1.png',
#  'id14-Moderate_p15_dis1.8O5_angle0R2_elev110U1.png',
#  'id12-Base_p13_dis1.85I2_angle180R3_elev15D1.png',
#  'id13-Severe_p11_dis1.7O2_angle137R2_elev15D1.png',
#  'id14-Minor_p15_dis1.8O4_angle0L2_elev110U4.png',
#  'id13-Base_p2_dis1.9O3_angle0R1_elev20U2.png',
#  'id2-Moderate_p1_dis1.8I4_angle0L3_elev8U1.png',
#  'id12-Base_p5_dis1.5I4_angle73R1_elev35D3.png',
#  'id8-Moderate_p7_dis1.75O2_angle40R4_elev30U4.png',
#  'id13-Moderate_p15_dis1.8O5_angle0_elev110U4.png',
#  'id26-Severe_p14_dis1.85_angle180L3_elev20U1.png',
#  'id10-Base_p15_dis1.8I4_angle0L4_elev110U3.png',
#  'id14-Moderate_p8_dis1.8O5_angle320_elev30D3.png',
#  'id10-Moderate_p2_dis1.9I4_angle0_elev20.png',
#  'id13-Severe_p2_dis1.9I5_angle0R3_elev20U3.png',
#  'id14-Moderate_p14_dis1.95I3_angle180_elev20U4.png',
#  'id2-Moderate_p8_dis1.7I5_angle320L1_elev30D3.png',
#  'id2-Base_p14_dis1.8O1_angle180_elev20U1.png',
#  'id10-Base_p8_dis1.75O1_angle320R1_elev30D2.png',
#  'id12-Moderate_p10_dis1.65O2_angle253R4_elev35U4.png',
#  'id2-Moderate_p6_dis1.5I4_angle287L2_elev30.png',
#  'id8-Minor_p3_dis1.8O2_angle43R3_elev15U4.png',
#  'id8-Minor_p6_dis1.5_angle287R1_elev30U4.png',
#  'id26-Moderate_p7_dis1.75O3_angle40L1_elev30U1.png',
#  'id12-Minor_p3_dis1.8O3_angle43L1_elev15U1.png',
#  'id8-Base_p13_dis1.85I4_angle180L3_elev15.png',
#  'id14-Base_p4_dis1.8_angle317L4_elev15D1.png',
#  'id8-Severe_p1_dis1.85O1_angle0_elev8D4.png',
#  'id10-Moderate_p7_dis1.75O4_angle40L3_elev30U4.png',
#  'id6-Moderate_p14_dis1.95_angle180L1_elev20D1.png',
#  'id6-Base_p4_dis1.8O3_angle317R2_elev15.png',
#  'id8-Moderate_p3_dis1.8O3_angle43L1_elev15D3.png',
#  'id8-Moderate_p14_dis1.85O1_angle180R2_elev20D3.png',
#  'id13-Base_p2_dis1.9I5_angle0L4_elev20D1.png',
#  'id14-Severe_p6_dis1.5I2_angle287L2_elev30U2.png',
#  'id8-Minor_p3_dis1.8I2_angle43R4_elev15U2.png',
#  'id26-Base_p1_dis1.85O1_angle0L3_elev8.png',
#  'id12-Base_p2_dis1.85I3_angle0L1_elev20D2.png',
#  'id6-Severe_p2_dis1.9O2_angle0R3_elev20.png',
#  'id2-Minor_p6_dis1.5I2_angle287R1_elev30U4.png',
#  'id26-Moderate_p10_dis1.65O5_angle253L4_elev30D4.png',
#  'id8-Minor_p6_dis1.5I5_angle287L1_elev30U2.png',
#  'id6-Severe_p3_dis1.8_angle43R3_elev15D4.png',
#  'id6-Minor_p7_dis1.75I2_angle40R1_elev30U1.png',
#  'id8-Severe_p5_dis1.5O3_angle73R4_elev30U1.png',
#  'id2-Moderate_p3_dis1.75O4_angle43L2_elev15.png',
#  'id14-Moderate_p13_dis1.95I4_angle180R4_elev15D2.png',
#  'id2-Severe_p15_dis1.8I4_angle0L3_elev110D3.png',
#  'id13-Base_p12_dis1.7O2_angle223R3_elev15U4.png',
#  'id14-Severe_p15_dis1.8I4_angle0_elev110D4.png',
#  'id10-Severe_p12_dis1.75O3_angle223_elev15U1.png',
#  'id8-Base_p6_dis1.5I2_angle287R3_elev30D1.png',
#  'id2-Minor_p6_dis1.5O4_angle287R4_elev30D1.png',
#  'id14-Severe_p7_dis1.8I2_angle40_elev30D2.png',
#  'id14-Minor_p12_dis1.75O4_angle223L3_elev15U3.png',
#  'id2-Base_p2_dis1.8I1_angle0L2_elev20D3.png',
#  'id10-Severe_p13_dis1.95O4_angle180L2_elev15U2.png',
#  'id8-Minor_p2_dis1.85I4_angle0R3_elev20D2.png',
#  'id12-Moderate_p10_dis1.65O1_angle253R1_elev35U4.png',
#  'id26-Severe_p3_dis1.8O2_angle43R2_elev15U4.png',
#  'id10-Severe_p13_dis1.95O4_angle180L1_elev15D1.png',
#  'id14-Base_p9_dis1.65O2_angle107L2_elev30D1.png',
#  'id6-Base_p2_dis1.9O2_angle0R2_elev20U2.png',
#  'id26-Severe_p6_dis1.5I4_angle287R1_elev30D4.png',
#  'id6-Minor_p3_dis1.8O1_angle43L1_elev15U3.png',
#  'id8-Moderate_p14_dis1.85O3_angle180R1_elev20U2.png',
#  'id13-Base_p4_dis1.8I1_angle317R2_elev15D2.png',
#  'id13-Minor_p2_dis1.9O2_angle0L4_elev20U2.png',
#  'id14-Severe_p3_dis1.8O2_angle43L4_elev15D2.png',
#  'id26-Minor_p5_dis1.5O1_angle73L1_elev30D3.png',
#  'id12-Base_p3_dis1.8I5_angle43L4_elev15U4.png',
#  'id10-Moderate_p1_dis1.9O1_angle0R4_elev8D2.png',
#  'id2-Severe_p2_dis1.8O5_angle0L4_elev20U3.png',
#  'id2-Minor_p13_dis1.8I4_angle180R2_elev15U4.png',
#  'id2-Severe_p8_dis1.7_angle320L3_elev30D1.png',
#  'id10-Base_p1_dis1.9O2_angle0L1_elev8D4.png',
#  'id6-Base_p5_dis1.5O2_angle73L3_elev30D2.png',
#  'id14-Moderate_p9_dis1.65I2_angle107R1_elev30U1.png',
#  'id6-Moderate_p5_dis1.5O3_angle73R1_elev30D1.png',
#  'id26-Minor_p13_dis1.85I1_angle180R4_elev15U3.png',
#  'id14-Base_p8_dis1.8_angle320R4_elev30D2.png',
#  'id13-Minor_p15_dis1.8O3_angle0R2_elev110D1.png',
#  'id12-Moderate_p15_dis1.8O1_angle0L4_elev110U3.png',
#  'id12-Severe_p11_dis1.75I4_angle137R2_elev15D3.png',
#  'id12-Base_p10_dis1.65O4_angle253_elev35U4.png',
#  'id12-Minor_p1_dis1.85I2_angle0R1_elev8D2.png',
#  'id6-Severe_p1_dis1.9O3_angle0R3_elev8D1.png',
#  'id8-Minor_p15_dis1.8O5_angle0L2_elev110D1.png',
#  'id2-Moderate_p5_dis1.5I1_angle73R2_elev30U2.png',
#  'id2-Moderate_p8_dis1.7I3_angle320R4_elev30U4.png',
#  'id13-Base_p8_dis1.75I3_angle320R2_elev30U1.png',
#  'id10-Moderate_p14_dis1.95O2_angle180R2_elev20U3.png',
#  'id10-Minor_p11_dis1.75O1_angle137R3_elev15U2.png',
#  'id13-Severe_p14_dis1.8I3_angle180R2_elev20D3.png',
#  'id13-Base_p15_dis1.8O1_angle0R3_elev110.png',
#  'id13-Base_p12_dis1.7O5_angle223L3_elev15D1.png',
#  'id2-Base_p11_dis1.7O4_angle137L4_elev15U3.png',
#  'id6-Base_p2_dis1.9O5_angle0L2_elev20D2.png',
#  'id2-Moderate_p11_dis1.7O4_angle137L2_elev15.png',
#  'id2-Moderate_p7_dis1.7O2_angle40_elev30D3.png',
#  'id10-Minor_p1_dis1.9O2_angle0L4_elev8D4.png',
#  'id14-Base_p1_dis1.95O5_angle0R1_elev8U3.png',
#  'id10-Moderate_p7_dis1.75O2_angle40L1_elev30D2.png',
#  'id8-Moderate_p13_dis1.85O1_angle180L4_elev15U3.png',
#  'id2-Base_p2_dis1.8O2_angle0R3_elev20.png',
#  'id26-Moderate_p8_dis1.75O5_angle320L1_elev30U3.png',
#  'id13-Severe_p14_dis1.8O3_angle180L3_elev20U2.png',
#  'id26-Minor_p13_dis1.85O2_angle180R4_elev15U4.png',
#  'id12-Base_p7_dis1.75I4_angle40L2_elev30U1.png',
#  'id26-Base_p6_dis1.5O4_angle287R3_elev30U3.png',
#  'id14-Severe_p15_dis1.8O3_angle0R2_elev110U2.png',
#  'id26-Base_p14_dis1.85O1_angle180L2_elev20D1.png',
#  'id6-Severe_p15_dis1.8I1_angle0L1_elev110.png',
#  'id26-Minor_p15_dis1.8O1_angle0L3_elev110U2.png',
#  'id12-Minor_p10_dis1.65I3_angle253L2_elev35D3.png',
#  'id6-Moderate_p11_dis1.75I5_angle137R4_elev15U1.png',
#  'id8-Base_p14_dis1.85I3_angle180L2_elev20U1.png',
#  'id13-Minor_p3_dis1.8I5_angle43_elev15U2.png',
#  'id14-Moderate_p7_dis1.8O3_angle40L4_elev30U1.png',
#  'id12-Moderate_p4_dis1.8I5_angle317L3_elev15D1.png',
#  'id13-Base_p6_dis1.5I4_angle287L1_elev30U4.png',
#  'id8-Moderate_p15_dis1.8I3_angle0L1_elev110U4.png',
#  'id6-Base_p1_dis1.9I5_angle0L1_elev8U3.png',
#  'id6-Severe_p13_dis1.95O3_angle180L3_elev15U4.png',
#  'id6-Severe_p8_dis1.75I4_angle320R2_elev30U3.png',
#  'id8-Minor_p3_dis1.8O5_angle43R1_elev15U2.png',
#  'id26-Minor_p12_dis1.75O2_angle223L3_elev15U1.png',
#  'id2-Moderate_p12_dis1.7O2_angle223R3_elev15.png',
#  'id6-Severe_p5_dis1.5O2_angle73R4_elev30.png',
#  'id10-Base_p4_dis1.8I4_angle317R3_elev15.png',
#  'id12-Minor_p14_dis1.85_angle180R1_elev25D4.png',
#  'id14-Severe_p15_dis1.8O3_angle0_elev110U1.png',
#  'id12-Minor_p10_dis1.65O3_angle253R2_elev35U1.png',
#  'id13-Moderate_p6_dis1.5_angle287R1_elev30D3.png',
#  'id6-Moderate_p6_dis1.5O5_angle287R4_elev30U1.png',
#  'id26-Severe_p15_dis1.8O2_angle0R1_elev110D1.png',
#  'id14-Minor_p14_dis1.95I1_angle180L3_elev20U1.png',
#  'id12-Severe_p9_dis1.65O5_angle107R2_elev35D2.png',
#  'id12-Minor_p9_dis1.65O1_angle107_elev35D3.png',
#  'id6-Minor_p13_dis1.95I3_angle180_elev15U1.png',
#  'id6-Moderate_p8_dis1.75O3_angle320R3_elev30U2.png',
#  'id26-Severe_p8_dis1.75O5_angle320_elev30U3.png',
#  'id2-Minor_p15_dis1.8O4_angle0R2_elev110U3.png',
#  'id10-Base_p4_dis1.8O5_angle317L3_elev15U2.png',
#  'id12-Base_p12_dis1.75_angle223L2_elev15D3.png',
#  'id2-Moderate_p13_dis1.8_angle180L2_elev15U3.png',
#  'id14-Severe_p6_dis1.5I4_angle287R2_elev30D4.png',
#  'id10-Severe_p12_dis1.75I2_angle223R4_elev15D3.png',
#  'id8-Severe_p15_dis1.8I1_angle0R4_elev110.png',
#  'id14-Moderate_p12_dis1.75O5_angle223R2_elev15U4.png',
#  'id13-Minor_p4_dis1.8I1_angle317_elev15U1.png',
#  'id14-Moderate_p12_dis1.75O4_angle223R4_elev15D3.png',
#  'id12-Moderate_p4_dis1.8O1_angle317L3_elev15.png',
#  'id2-Severe_p5_dis1.5I4_angle73L2_elev30U2.png',
#  'id2-Severe_p1_dis1.8_angle0R1_elev8.png',
#  'id6-Moderate_p13_dis1.95_angle180L2_elev15.png',
#  'id2-Moderate_p8_dis1.7O1_angle320L1_elev30.png',
#  'id2-Minor_p12_dis1.7O4_angle223R4_elev15U3.png',
#  'id13-Minor_p14_dis1.8I3_angle180R4_elev20D4.png',
#  'id8-Base_p12_dis1.75O3_angle223_elev15U2.png',
#  'id8-Base_p6_dis1.5O2_angle287R2_elev30U4.png',
#  'id10-Minor_p1_dis1.9_angle0L3_elev8U1.png',
#  'id2-Severe_p2_dis1.8_angle0R2_elev20U3.png',
#  'id13-Severe_p6_dis1.5O1_angle287L4_elev30D3.png',
#  'id10-Severe_p6_dis1.5O2_angle287R2_elev30D1.png',
#  'id12-Base_p5_dis1.5I4_angle73R2_elev35U1.png',
#  'id14-Severe_p8_dis1.8O1_angle320L2_elev30U1.png',
#  'id6-Base_p11_dis1.75O1_angle137R3_elev15U3.png',
#  'id26-Moderate_p15_dis1.8O1_angle0R2_elev110U3.png',
#  'id14-Moderate_p15_dis1.8I2_angle0R2_elev110D1.png',
#  'id8-Base_p14_dis1.85I2_angle180R2_elev20U4.png',
#  'id14-Minor_p11_dis1.75I4_angle137R3_elev15D2.png',
#  'id12-Base_p7_dis1.75O5_angle40R1_elev30D3.png',
#  'id14-Base_p12_dis1.75O3_angle223R3_elev15U3.png',
#  'id2-Moderate_p11_dis1.7_angle137R4_elev15D1.png',
#  'id2-Minor_p13_dis1.8O5_angle180L2_elev15D4.png',
#  'id13-Base_p3_dis1.8O1_angle43L3_elev15D1.png',
#  'id10-Base_p5_dis1.5I4_angle73R1_elev30U3.png',
#  'id26-Base_p14_dis1.85O1_angle180L1_elev20U4.png',
#  'id8-Base_p11_dis1.75I3_angle137_elev15U3.png',
#  'id13-Base_p7_dis1.75O1_angle40R2_elev30D4.png',
#  'id8-Minor_p5_dis1.5_angle73L3_elev30.png',
#  'id10-Moderate_p12_dis1.75I2_angle223L2_elev15U2.png',
#  'id26-Moderate_p4_dis1.8O3_angle317L2_elev15D2.png',
#  'id2-Minor_p2_dis1.8I2_angle0R3_elev20U1.png',
#  'id6-Minor_p12_dis1.75I5_angle223R4_elev15U4.png',
#  'id8-Severe_p12_dis1.75O1_angle223R3_elev15U1.png',
#  'id12-Base_p7_dis1.75O3_angle40R3_elev30U4.png',
#  'id8-Base_p4_dis1.8O5_angle317R4_elev15U2.png',
#  'id14-Severe_p6_dis1.5O3_angle287L1_elev30D2.png',
#  'id12-Severe_p4_dis1.8O4_angle317R2_elev15U3.png',
#  'id2-Moderate_p7_dis1.7O3_angle40L4_elev30D3.png',
#  'id2-Minor_p15_dis1.8I1_angle0R1_elev110U4.png',
#  'id14-Base_p6_dis1.5_angle287R4_elev30D1.png',
#  'id10-Minor_p13_dis1.95I1_angle180R1_elev15U1.png',
#  'id6-Base_p15_dis1.8_angle0L1_elev110D2.png',
#  'id26-Moderate_p7_dis1.75O4_angle40R4_elev30D2.png',
#  'id10-Minor_p7_dis1.75_angle40L4_elev30U4.png',
#  'id14-Moderate_p8_dis1.8I5_angle320L3_elev30U1.png',
#  'id10-Base_p11_dis1.75I1_angle137L4_elev15D4.png',
#  'id26-Moderate_p11_dis1.75I1_angle137R3_elev15U3.png',
#  'id13-Moderate_p13_dis1.8_angle180_elev15D4.png',
#  'id26-Base_p13_dis1.85_angle180L4_elev15D2.png',
#  'id6-Moderate_p11_dis1.75I5_angle137L1_elev15U2.png',
#  'id13-Severe_p12_dis1.7I2_angle223L2_elev15.png',
#  'id10-Moderate_p5_dis1.5_angle73_elev30U1.png',
#  'id13-Moderate_p12_dis1.7I5_angle223R2_elev15D1.png',
#  'id10-Severe_p6_dis1.5_angle287_elev30D3.png',
#  'id6-Severe_p5_dis1.5I5_angle73R1_elev30D4.png',
#  'id26-Minor_p14_dis1.85I3_angle180_elev20D2.png',
#  'id2-Moderate_p12_dis1.7O1_angle223R4_elev15D1.png',
#  'id8-Severe_p6_dis1.5I1_angle287L3_elev30U1.png',
#  'id12-Minor_p4_dis1.8I3_angle317R1_elev15D2.png',
#  'id2-Severe_p4_dis1.75O5_angle317L2_elev15D4.png',
#  'id2-Base_p1_dis1.8I2_angle0L1_elev8U4.png',
#  'id26-Moderate_p5_dis1.5O5_angle73R3_elev30U1.png',
#  'id2-Moderate_p4_dis1.75I3_angle317R1_elev15D1.png',
#  'id6-Moderate_p8_dis1.75O1_angle320L4_elev30D3.png',
#  'id2-Moderate_p12_dis1.7I2_angle223L1_elev15D3.png',
#  'id8-Minor_p11_dis1.75I4_angle137L4_elev15D4.png',
#  'id14-Minor_p14_dis1.95I1_angle180R4_elev20U3.png',
#  'id13-Moderate_p13_dis1.8I3_angle180R4_elev15U4.png',
#  'id14-Minor_p8_dis1.8O1_angle320R1_elev30U1.png',
#  'id12-Moderate_p6_dis1.5O3_angle287R1_elev35D2.png',
#  'id10-Minor_p5_dis1.5I3_angle73L1_elev30U4.png',
#  'id12-Base_p5_dis1.5O2_angle73L1_elev35U4.png',
#  'id12-Severe_p3_dis1.8I2_angle43R1_elev15D2.png',
#  'id10-Minor_p5_dis1.5I5_angle73L3_elev30D3.png',
#  'id26-Severe_p6_dis1.5I3_angle287R3_elev30D1.png',
#  'id2-Moderate_p2_dis1.8I5_angle0R4_elev20D3.png',
#  'id13-Severe_p6_dis1.5I1_angle287R4_elev30U3.png',
#  'id8-Severe_p11_dis1.75O3_angle137L2_elev15D4.png',
#  'id6-Minor_p15_dis1.8O2_angle0L2_elev110D1.png',
#  'id6-Base_p15_dis1.8O4_angle0L4_elev110D1.png',
#  'id12-Moderate_p5_dis1.5I1_angle73L3_elev35U2.png',
#  'id2-Base_p15_dis1.8I5_angle0L1_elev110D3.png',
#  'id12-Moderate_p14_dis1.85O4_angle180R1_elev25D2.png',
#  'id10-Moderate_p13_dis1.95I2_angle180L1_elev15D3.png',
#  'id10-Severe_p12_dis1.75O4_angle223_elev15D1.png',
#  'id10-Minor_p12_dis1.75O3_angle223R4_elev15U2.png',
#  'id12-Base_p13_dis1.85I3_angle180L1_elev15U2.png',
#  'id6-Minor_p7_dis1.75O3_angle40L2_elev30.png',
#  'id2-Minor_p11_dis1.7I1_angle137L1_elev15U3.png',
#  'id13-Severe_p13_dis1.8O5_angle180R2_elev15U3.png',
#  'id2-Minor_p13_dis1.8O1_angle180L4_elev15U2.png',
#  'id13-Moderate_p6_dis1.5O2_angle287L2_elev30D2.png',
#  'id12-Moderate_p14_dis1.85I4_angle180R2_elev25U1.png',
#  'id6-Moderate_p3_dis1.8O4_angle43L4_elev15D2.png',
#  'id10-Minor_p12_dis1.75I2_angle223R3_elev15U3.png',
#  'id2-Minor_p15_dis1.8I5_angle0L4_elev110D3.png',
#  'id13-Base_p3_dis1.8O5_angle43L3_elev15U1.png',
#  'id10-Moderate_p8_dis1.75I2_angle320L1_elev30D4.png',
#  'id12-Minor_p5_dis1.5O3_angle73L1_elev35D3.png',
#  'id6-Base_p12_dis1.75O5_angle223R3_elev15U1.png',
#  'id6-Moderate_p14_dis1.95I3_angle180L3_elev20U3.png',
#  'id8-Base_p1_dis1.85O2_angle0L4_elev8D1.png',
#  'id12-Severe_p12_dis1.75O1_angle223R3_elev15U2.png',
#  'id8-Severe_p5_dis1.5I2_angle73L4_elev30.png',
#  'id14-Severe_p6_dis1.5I5_angle287R1_elev30U2.png',
#  'id8-Severe_p14_dis1.85_angle180R4_elev20D4.png',
#  'id13-Severe_p2_dis1.9O5_angle0R4_elev20D1.png',
#  'id10-Moderate_p7_dis1.75O1_angle40L4_elev30D1.png',
#  'id14-Minor_p10_dis1.65O3_angle253R3_elev30.png',
#  'id14-Moderate_p15_dis1.8I3_angle0L3_elev110D2.png',
#  'id6-Moderate_p12_dis1.75_angle223_elev15U1.png',
#  'id12-Severe_p12_dis1.75O3_angle223R4_elev15U4.png',
#  'id26-Severe_p1_dis1.85I1_angle0R4_elev8.png',
#  'id26-Severe_p9_dis1.65O3_angle107R4_elev30D3.png',
#  'id26-Severe_p13_dis1.85I1_angle180L2_elev15.png',
#  'id10-Minor_p11_dis1.75O3_angle137L2_elev15D3.png',
#  'id6-Moderate_p2_dis1.9_angle0_elev20U4.png',
#  'id6-Base_p11_dis1.75I1_angle137L3_elev15.png',
#  'id12-Severe_p14_dis1.85I3_angle180R4_elev25D2.png',
#  'id6-Severe_p13_dis1.95O4_angle180R3_elev15.png',
#  'id2-Minor_p3_dis1.75I1_angle43L1_elev15U3.png',
#  'id2-Moderate_p13_dis1.8I5_angle180L3_elev15U2.png',
#  'id2-Moderate_p2_dis1.8I1_angle0R2_elev20.png',
#  'id12-Minor_p8_dis1.75_angle320R1_elev30D3.png',
#  'id10-Moderate_p4_dis1.8I1_angle317_elev15D3.png',
#  'id2-Severe_p12_dis1.7I5_angle223L3_elev15U3.png',
#  'id10-Moderate_p7_dis1.75_angle40L4_elev30D2.png',
#  'id13-Minor_p13_dis1.8I5_angle180L3_elev15U2.png',
#  'id6-Base_p6_dis1.5O1_angle287R2_elev30U2.png',
#  'id8-Base_p5_dis1.5O1_angle73_elev30U3.png',
#  'id2-Moderate_p14_dis1.8I2_angle180L3_elev20D3.png',
#  'id14-Minor_p5_dis1.5O3_angle73R3_elev30U4.png',
#  'id14-Minor_p7_dis1.8O1_angle40_elev30U4.png',
#  'id14-Base_p3_dis1.8O5_angle43L4_elev15U2.png',
#  'id14-Base_p3_dis1.8I5_angle43L4_elev15D3.png',
#  'id2-Moderate_p1_dis1.8O4_angle0_elev8U1.png',
#  'id8-Minor_p4_dis1.8O1_angle317R4_elev15D2.png',
#  'id8-Minor_p3_dis1.8O4_angle43R4_elev15.png',
#  'id26-Minor_p7_dis1.75_angle40L3_elev30D1.png',
#  'id2-Minor_p15_dis1.8I4_angle0L2_elev110U4.png',
#  'id10-Moderate_p4_dis1.8I3_angle317R2_elev15U1.png',
#  'id13-Base_p1_dis1.9I5_angle0L3_elev8D3.png',
#  'id12-Base_p4_dis1.8I2_angle317L2_elev15U2.png',
#  'id26-Base_p5_dis1.5I3_angle73L1_elev30.png',
#  'id6-Minor_p2_dis1.9O1_angle0R2_elev20D2.png',
#  'id26-Minor_p1_dis1.85I2_angle0R3_elev8U3.png',
#  'id12-Moderate_p14_dis1.85O5_angle180R4_elev25D2.png',
#  'id13-Minor_p15_dis1.8O4_angle0L1_elev110U4.png',
#  'id10-Severe_p11_dis1.75I1_angle137L2_elev15U1.png',
#  'id12-Minor_p2_dis1.85O4_angle0R1_elev20U1.png',
#  'id14-Severe_p2_dis1.95I2_angle0_elev20U2.png',
#  'id26-Severe_p3_dis1.8O1_angle43R2_elev15U2.png',
#  'id2-Moderate_p1_dis1.8I1_angle0_elev8D1.png',
#  'id13-Severe_p11_dis1.7O1_angle137R2_elev15U2.png',
#  'id13-Severe_p5_dis1.5O3_angle73L2_elev30.png',
#  'id26-Severe_p13_dis1.85I5_angle180L4_elev15U4.png',
#  'id13-Base_p1_dis1.9I4_angle0_elev8D1.png',
#  'id12-Base_p7_dis1.75O4_angle40_elev30U3.png',
#  'id10-Severe_p4_dis1.8O1_angle317R1_elev15U1.png',
#  'id6-Moderate_p12_dis1.75O1_angle223L2_elev15U4.png',
#  'id6-Minor_p5_dis1.5O4_angle73R4_elev30D2.png',
#  'id13-Base_p11_dis1.7I4_angle137L3_elev15D1.png',
#  'id26-Minor_p9_dis1.65I4_angle107L2_elev30D3.png',
#  'id10-Minor_p11_dis1.75I2_angle137L4_elev15U4.png',
#  'id10-Base_p8_dis1.75O4_angle320R1_elev30U4.png',
#  'id26-Moderate_p10_dis1.65I4_angle253R4_elev30D4.png',
#  'id13-Minor_p13_dis1.8O5_angle180R4_elev15U2.png',
#  'id13-Minor_p6_dis1.5I1_angle287L2_elev30U2.png',
#  'id6-Minor_p15_dis1.8O5_angle0R1_elev110D2.png',
#  'id8-Base_p4_dis1.8O1_angle317L3_elev15.png',
#  'id14-Minor_p10_dis1.65I2_angle253R3_elev30U3.png',
#  'id10-Severe_p4_dis1.8I2_angle317R3_elev15U2.png',
#  'id10-Minor_p14_dis1.95_angle180R3_elev20D1.png',
#  'id12-Moderate_p14_dis1.85I1_angle180L1_elev25D2.png',
#  'id12-Minor_p3_dis1.8I2_angle43_elev15D4.png',
#  'id2-Severe_p12_dis1.7O2_angle223L2_elev15D3.png',
#  'id14-Severe_p4_dis1.8I3_angle317R2_elev15D4.png',
#  'id12-Base_p2_dis1.85O1_angle0R2_elev20D2.png',
#  'id2-Moderate_p4_dis1.75O4_angle317L3_elev15D4.png',
#  'id14-Minor_p5_dis1.5I2_angle73_elev30D3.png',
#  'id2-Severe_p6_dis1.5I4_angle287R2_elev30D2.png',
#  'id6-Moderate_p3_dis1.8I4_angle43R4_elev15D1.png',
#  'id12-Minor_p11_dis1.75_angle137_elev15.png',
#  'id14-Base_p13_dis1.95O5_angle180R1_elev15U1.png',
#  'id26-Severe_p11_dis1.75O2_angle137R2_elev15U1.png',
#  'id6-Severe_p1_dis1.9I5_angle0L3_elev8.png',
#  'id12-Moderate_p11_dis1.75O1_angle137R4_elev15.png',
#  'id14-Base_p8_dis1.8I3_angle320L1_elev30U4.png',
#  'id26-Minor_p9_dis1.65I5_angle107R1_elev30U2.png',
#  'id12-Severe_p3_dis1.8O5_angle43L1_elev15U4.png',
#  'id8-Base_p13_dis1.85O1_angle180L3_elev15U1.png',
#  'id26-Minor_p11_dis1.75O5_angle137R4_elev15D2.png',
#  'id6-Base_p12_dis1.75_angle223L4_elev15.png',
#  'id10-Severe_p4_dis1.8I5_angle317L3_elev15U2.png',
#  'id8-Base_p4_dis1.8O3_angle317R3_elev15U4.png',
#  'id26-Moderate_p3_dis1.8O5_angle43R2_elev15U4.png',
#  'id14-Minor_p6_dis1.5I3_angle287R3_elev30D2.png',
#  'id8-Base_p1_dis1.85I4_angle0L3_elev8D2.png',
#  'id12-Base_p10_dis1.65I3_angle253L3_elev35U1.png',
#  'id14-Moderate_p13_dis1.95O1_angle180L3_elev15D4.png',
#  'id8-Severe_p6_dis1.5I4_angle287R2_elev30D1.png',
#  'id8-Moderate_p1_dis1.85I4_angle0R1_elev8.png',
#  'id13-Severe_p15_dis1.8O4_angle0L1_elev110D4.png',
#  'id12-Moderate_p9_dis1.65_angle107L1_elev35D2.png',
#  'id6-Minor_p1_dis1.9O1_angle0_elev8U3.png',
#  'id12-Base_p11_dis1.75O1_angle137L1_elev15U4.png',
#  'id10-Moderate_p4_dis1.8_angle317R3_elev15D4.png',
#  'id13-Minor_p5_dis1.5_angle73L2_elev30U1.png',
#  'id10-Moderate_p2_dis1.9I4_angle0L1_elev20U3.png',
#  'id13-Minor_p7_dis1.75I3_angle40_elev30U1.png',
#  'id2-Severe_p12_dis1.7O4_angle223L4_elev15U2.png',
#  'id13-Base_p5_dis1.5I1_angle73R3_elev30U4.png',
#  'id12-Minor_p4_dis1.8O4_angle317L3_elev15U3.png',
#  'id12-Moderate_p7_dis1.75O5_angle40L4_elev30U4.png',
#  'id26-Base_p13_dis1.85O5_angle180R3_elev15D4.png',
#  'id8-Severe_p2_dis1.85I4_angle0_elev20D2.png',
#  'id14-Moderate_p5_dis1.5O2_angle73R2_elev30U1.png',
#  'id26-Moderate_p12_dis1.75I3_angle223R4_elev15.png',
#  'id13-Minor_p14_dis1.8O4_angle180L2_elev20U4.png',
#  'id13-Severe_p8_dis1.75I1_angle320L2_elev30U1.png',
#  'id26-Minor_p6_dis1.5I3_angle287R2_elev30U3.png',
#  'id10-Minor_p8_dis1.75I3_angle320R2_elev30D3.png',
#  'id8-Base_p4_dis1.8O1_angle317L3_elev15U4.png',
#  'id26-Moderate_p1_dis1.85I2_angle0L1_elev8.png',
#  'id26-Base_p9_dis1.65O2_angle107L4_elev30.png',
#  'id2-Severe_p3_dis1.75I4_angle43R1_elev15D2.png',
#  'id10-Moderate_p14_dis1.95O3_angle180L1_elev20D3.png',
#  'id10-Minor_p1_dis1.9I5_angle0_elev8.png',
#  'id14-Base_p6_dis1.5O5_angle287_elev30D4.png',
#  'id8-Minor_p8_dis1.75O4_angle320_elev30.png',
#  'id2-Severe_p11_dis1.7O1_angle137R4_elev15.png',
#  'id14-Base_p6_dis1.5O2_angle287R2_elev30U4.png',
#  'id13-Base_p7_dis1.75_angle40R1_elev30D4.png',
#  'id14-Moderate_p3_dis1.8I5_angle43R3_elev15U2.png',
#  'id10-Moderate_p3_dis1.8I3_angle43R4_elev15U3.png',
#  'id26-Severe_p3_dis1.8O1_angle43L2_elev15U3.png',
#  'id2-Severe_p6_dis1.5I5_angle287R4_elev30U3.png',
#  'id2-Severe_p11_dis1.7I3_angle137_elev15U2.png',
#  'id6-Moderate_p2_dis1.9O4_angle0R1_elev20.png',
#  'id2-Severe_p7_dis1.7_angle40R3_elev30U4.png',
#  'id10-Moderate_p8_dis1.75_angle320_elev30D2.png',
#  'id12-Base_p1_dis1.85O4_angle0L1_elev8U2.png',
#  'id26-Base_p7_dis1.75I5_angle40R3_elev30D2.png',
#  'id10-Moderate_p12_dis1.75I4_angle223R4_elev15D3.png',
#  'id14-Moderate_p8_dis1.8O1_angle320L3_elev30D2.png',
#  'id12-Base_p15_dis1.8I1_angle0R1_elev110U4.png',
#  'id8-Base_p15_dis1.8_angle0R2_elev110D2.png',
#  'id10-Minor_p5_dis1.5_angle73L2_elev30U4.png',
#  'id13-Moderate_p4_dis1.8O3_angle317L2_elev15D2.png',
#  'id2-Minor_p13_dis1.8I5_angle180L1_elev15D4.png',
#  'id2-Severe_p8_dis1.7O2_angle320L2_elev30D2.png',
#  'id2-Minor_p2_dis1.8I2_angle0L1_elev20U2.png',
#  'id13-Minor_p5_dis1.5I1_angle73R1_elev30D2.png',
#  'id2-Minor_p2_dis1.8I1_angle0L4_elev20U2.png',
#  'id14-Minor_p3_dis1.8O3_angle43R3_elev15U3.png',
#  'id8-Severe_p9_dis1.65I3_angle107L1_elev30U1.png',
#  'id12-Severe_p9_dis1.65O3_angle107L3_elev35.png',
#  'id10-Moderate_p3_dis1.8I3_angle43R4_elev15U1.png',
#  'id26-Moderate_p11_dis1.75I5_angle137L1_elev15.png',
#  'id8-Minor_p12_dis1.75I3_angle223L4_elev15U4.png',
#  'id12-Minor_p13_dis1.85O4_angle180R3_elev15U2.png',
#  'id2-Minor_p8_dis1.7O2_angle320R3_elev30U3.png',
#  'id10-Moderate_p12_dis1.75O2_angle223R3_elev15U2.png',
#  'id8-Moderate_p8_dis1.75I4_angle320R1_elev30U4.png',
#  'id2-Base_p6_dis1.5O4_angle287L3_elev30D4.png',
#  'id8-Moderate_p14_dis1.85I3_angle180_elev20U4.png',
#  'id14-Moderate_p12_dis1.75I1_angle223R4_elev15U2.png',
#  'id26-Moderate_p11_dis1.75O4_angle137R1_elev15D4.png',
#  'id14-Minor_p9_dis1.65O3_angle107L4_elev30U3.png',
#  'id2-Base_p6_dis1.5O2_angle287R2_elev30D3.png',
#  'id14-Base_p2_dis1.95O5_angle0R4_elev20U2.png',
#  'id14-Base_p14_dis1.95O5_angle180L2_elev20U2.png',
#  'id13-Severe_p11_dis1.7I3_angle137R3_elev15U1.png',
#  'id13-Minor_p4_dis1.8O3_angle317R3_elev15D2.png',
#  'id14-Severe_p15_dis1.8I3_angle0L4_elev110D3.png',
#  'id14-Moderate_p9_dis1.65_angle107R2_elev30D2.png',
#  'id12-Moderate_p8_dis1.75I3_angle320L1_elev30.png',
#  'id10-Base_p2_dis1.9I1_angle0L2_elev20U2.png',
#  'id14-Moderate_p5_dis1.5O5_angle73R2_elev30D2.png',
#  'id13-Minor_p6_dis1.5I5_angle287L1_elev30D2.png',
#  'id8-Moderate_p13_dis1.85O5_angle180L4_elev15U1.png',
#  'id12-Severe_p4_dis1.8O2_angle317L2_elev15U3.png',
#  'id6-Base_p8_dis1.75_angle320L1_elev30U4.png',
#  'id10-Severe_p3_dis1.8_angle43R4_elev15U4.png',
#  'id13-Severe_p12_dis1.7I2_angle223L1_elev15D3.png',
#  'id26-Moderate_p11_dis1.75I1_angle137L4_elev15D4.png',
#  'id10-Severe_p6_dis1.5I4_angle287R3_elev30D4.png',
#  'id6-Severe_p14_dis1.95O1_angle180R4_elev20U4.png',
#  'id6-Moderate_p6_dis1.5O4_angle287L1_elev30D3.png',
#  'id14-Minor_p3_dis1.8_angle43_elev15D2.png',
#  'id10-Severe_p1_dis1.9O3_angle0R2_elev8U3.png',
#  'id13-Moderate_p4_dis1.8I3_angle317L4_elev15D3.png',
#  'id13-Severe_p1_dis1.9O1_angle0R4_elev8U3.png',
#  'id14-Severe_p15_dis1.8I4_angle0L3_elev110D2.png',
#  'id2-Severe_p14_dis1.8O4_angle180L4_elev20U2.png',
#  'id10-Severe_p11_dis1.75O4_angle137R2_elev15U1.png',
#  'id10-Minor_p1_dis1.9I2_angle0L1_elev8D2.png',
#  'id6-Minor_p2_dis1.9O2_angle0L2_elev20U3.png',
#  'id26-Base_p9_dis1.65O1_angle107L2_elev30D1.png',
#  'id10-Base_p6_dis1.5O2_angle287L1_elev30U3.png',
#  'id10-Severe_p12_dis1.75O1_angle223R2_elev15U1.png',
#  'id8-Moderate_p12_dis1.75I1_angle223R1_elev15D3.png',
#  'id8-Severe_p6_dis1.5I2_angle287R3_elev30D3.png',
#  'id26-Severe_p1_dis1.85O3_angle0L4_elev8U4.png',
#  'id12-Minor_p13_dis1.85I3_angle180R2_elev15U2.png',
#  'id14-Minor_p5_dis1.5O5_angle73L3_elev30D2.png',
#  'id13-Moderate_p11_dis1.7I4_angle137L2_elev15U3.png',
#  'id26-Severe_p11_dis1.75_angle137R3_elev15U4.png',
#  'id12-Base_p7_dis1.75O4_angle40R3_elev30U4.png',
#  'id26-Base_p5_dis1.5O2_angle73L1_elev30D3.png',
#  'id13-Minor_p4_dis1.8O4_angle317L4_elev15U2.png',
#  'id14-Severe_p1_dis1.95I4_angle0R2_elev8U1.png',
#  'id26-Minor_p7_dis1.75O1_angle40L4_elev30D1.png',
#  'id8-Severe_p6_dis1.5I5_angle287_elev30U2.png',
#  'id8-Severe_p14_dis1.85O2_angle180L4_elev20D2.png',
#  'id2-Minor_p3_dis1.75I5_angle43L1_elev15U4.png',
#  'id10-Severe_p13_dis1.95O4_angle180R1_elev15D4.png',
#  'id6-Severe_p5_dis1.5O2_angle73L3_elev30D4.png',
#  'id10-Severe_p4_dis1.8O4_angle317R2_elev15U4.png',
#  'id26-Moderate_p10_dis1.65_angle253R3_elev30U3.png',
#  'id12-Severe_p4_dis1.8I5_angle317R1_elev15D2.png',
#  'id8-Base_p9_dis1.65_angle107R1_elev30D3.png',
#  'id26-Severe_p5_dis1.5O5_angle73L4_elev30U3.png',
#  'id26-Moderate_p3_dis1.8O4_angle43R1_elev15U3.png',
#  'id26-Moderate_p6_dis1.5O4_angle287_elev30U1.png',
#  'id8-Minor_p11_dis1.75I3_angle137R3_elev15U1.png',
#  'id14-Severe_p9_dis1.65I3_angle107R1_elev30.png',
#  'id10-Base_p7_dis1.75O5_angle40L1_elev30D2.png',
#  'id6-Severe_p11_dis1.75I3_angle137L4_elev15U3.png',
#  'id8-Severe_p15_dis1.8O3_angle0L2_elev110U3.png',
#  'id13-Moderate_p2_dis1.9O4_angle0R3_elev20.png',
#  'id6-Base_p15_dis1.8O1_angle0L2_elev110.png',
#  'id13-Moderate_p14_dis1.8O3_angle180R4_elev20U4.png',
#  'id13-Severe_p13_dis1.8I4_angle180R3_elev15D1.png',
#  'id8-Moderate_p3_dis1.8I2_angle43L3_elev15D1.png',
#  'id14-Minor_p14_dis1.95I1_angle180L1_elev20U1.png',
#  'id26-Moderate_p8_dis1.75I4_angle320R3_elev30U2.png',
#  'id26-Moderate_p5_dis1.5I2_angle73R2_elev30D3.png',
#  'id6-Severe_p13_dis1.95_angle180L3_elev15D4.png',
#  'id14-Moderate_p13_dis1.95I3_angle180L1_elev15D2.png',
#  'id12-Severe_p5_dis1.5I4_angle73L1_elev35D4.png',
#  'id6-Base_p3_dis1.8O5_angle43R4_elev15.png',
#  'id14-Minor_p5_dis1.5I3_angle73_elev30D2.png',
#  'id14-Minor_p10_dis1.65I3_angle253R3_elev30D4.png',
#  'id12-Base_p5_dis1.5O2_angle73L2_elev35.png',
#  'id26-Minor_p6_dis1.5O4_angle287R1_elev30D1.png',
#  'id13-Minor_p4_dis1.8O4_angle317L2_elev15U4.png',
#  'id2-Moderate_p13_dis1.8I4_angle180R4_elev15D1.png',
#  'id8-Base_p3_dis1.8O2_angle43R3_elev15D2.png',
#  'id8-Minor_p9_dis1.65I3_angle107L3_elev30.png',
#  'id14-Base_p12_dis1.75O5_angle223R1_elev15D1.png',
#  'id2-Base_p2_dis1.8I1_angle0L1_elev20U1.png',
#  'id13-Base_p8_dis1.75O5_angle320R4_elev30U3.png',
#  'id8-Base_p13_dis1.85O2_angle180R2_elev15U1.png',
#  'id12-Moderate_p14_dis1.85O3_angle180L3_elev25U2.png',
#  'id6-Severe_p4_dis1.8I2_angle317_elev15.png',
#  'id8-Moderate_p7_dis1.75I4_angle40L1_elev30U4.png',
#  'id10-Moderate_p3_dis1.8O3_angle43R4_elev15D4.png',
#  'id13-Moderate_p1_dis1.9I1_angle0L4_elev8D2.png',
#  'id10-Minor_p14_dis1.95O3_angle180L3_elev20D1.png',
#  'id26-Minor_p5_dis1.5O1_angle73L3_elev30D2.png',
#  'id12-Minor_p4_dis1.8O4_angle317R4_elev15U1.png',
#  'id8-Moderate_p13_dis1.85I4_angle180_elev15D3.png',
#  'id12-Moderate_p7_dis1.75O5_angle40L3_elev30U3.png',
#  'id12-Moderate_p1_dis1.85_angle0R3_elev8D2.png',
#  'id12-Severe_p3_dis1.8O2_angle43_elev15U2.png',
#  'id8-Moderate_p12_dis1.75O2_angle223R2_elev15U1.png',
#  'id6-Severe_p6_dis1.5O3_angle287_elev30U2.png',
#  'id14-Moderate_p10_dis1.65O2_angle253R2_elev30D4.png',
#  'id26-Severe_p11_dis1.75I4_angle137L3_elev15D1.png',
#  'id6-Minor_p12_dis1.75I1_angle223L4_elev15U3.png',
#  'id13-Severe_p7_dis1.75I4_angle40R2_elev30U4.png',
#  'id26-Severe_p2_dis1.85I1_angle0L3_elev20.png',
#  'id26-Minor_p15_dis1.8O2_angle0R1_elev110.png',
#  'id8-Moderate_p12_dis1.75O3_angle223L3_elev15U2.png',
#  'id8-Base_p12_dis1.75_angle223R1_elev15U4.png',
#  'id8-Severe_p8_dis1.75O4_angle320_elev30D1.png',
#  'id2-Base_p3_dis1.75I1_angle43L2_elev15D1.png',
#  'id8-Severe_p8_dis1.75I3_angle320R1_elev30U4.png',
#  'id2-Severe_p8_dis1.7I1_angle320L1_elev30D1.png',
#  'id14-Minor_p11_dis1.75_angle137R2_elev15U1.png',
#  'id8-Base_p13_dis1.85I3_angle180R4_elev15U4.png',
#  'id26-Minor_p12_dis1.75I2_angle223L2_elev15D1.png',
#  'id8-Base_p2_dis1.85I4_angle0L4_elev20U2.png',
#  'id10-Severe_p1_dis1.9I1_angle0L1_elev8U1.png',
#  'id8-Minor_p3_dis1.8I3_angle43R2_elev15U2.png',
#  'id26-Severe_p2_dis1.85O5_angle0L2_elev20U2.png',
#  'id6-Severe_p11_dis1.75I1_angle137L2_elev15D1.png',
#  'id8-Base_p8_dis1.75O3_angle320L2_elev30D4.png',
#  'id12-Base_p7_dis1.75O3_angle40R2_elev30U1.png',
#  'id8-Base_p5_dis1.5O2_angle73R1_elev30D1.png',
#  'id13-Minor_p12_dis1.7I3_angle223R1_elev15U1.png',
#  'id26-Base_p1_dis1.85O3_angle0_elev8U4.png',
#  'id12-Severe_p8_dis1.75O5_angle320R2_elev30U4.png',
#  'id13-Minor_p7_dis1.75I4_angle40R2_elev30.png',
#  'id6-Minor_p15_dis1.8O2_angle0L3_elev110D1.png',
#  'id10-Minor_p14_dis1.95O2_angle180L2_elev20U2.png',
#  'id2-Minor_p6_dis1.5I5_angle287R3_elev30U1.png',
#  'id6-Base_p14_dis1.95O3_angle180R1_elev20.png',
#  'id2-Moderate_p13_dis1.8I4_angle180L2_elev15U3.png',
#  'id2-Minor_p8_dis1.7O4_angle320R3_elev30D2.png',
#  'id13-Minor_p6_dis1.5O5_angle287L4_elev30D3.png',
#  'id26-Severe_p14_dis1.85O2_angle180L4_elev20D1.png',
#  'id26-Moderate_p4_dis1.8I1_angle317_elev15U2.png',
#  'id12-Base_p9_dis1.65O4_angle107R4_elev35U4.png',
#  'id26-Severe_p10_dis1.65O5_angle253R1_elev30U4.png',
#  'id6-Severe_p5_dis1.5I3_angle73R4_elev30.png',
#  'id8-Severe_p1_dis1.85I2_angle0L3_elev8D2.png',
#  'id6-Severe_p5_dis1.5I4_angle73R3_elev30D2.png',
#  'id2-Base_p15_dis1.8I3_angle0R2_elev110U2.png',
#  'id26-Moderate_p11_dis1.75I1_angle137L3_elev15U3.png',
#  'id8-Moderate_p9_dis1.65I4_angle107R4_elev30D2.png',
#  'id12-Minor_p2_dis1.85O2_angle0_elev20D1.png',
#  'id8-Minor_p9_dis1.65O5_angle107_elev30D2.png',
#  'id14-Moderate_p11_dis1.75I5_angle137L1_elev15D4.png',
#  'id12-Minor_p13_dis1.85O3_angle180_elev15U4.png',
#  'id26-Moderate_p5_dis1.5O2_angle73L3_elev30U1.png',
#  'id13-Moderate_p2_dis1.9I3_angle0R1_elev20U3.png',
#  'id8-Severe_p8_dis1.75I2_angle320_elev30U1.png',
#  'id12-Severe_p1_dis1.85I3_angle0R4_elev8D1.png',
#  'id6-Severe_p2_dis1.9I1_angle0L1_elev20D3.png',
#  'id8-Moderate_p8_dis1.75O2_angle320L3_elev30D1.png',
#  'id10-Minor_p7_dis1.75I3_angle40L1_elev30D4.png',
#  'id2-Base_p4_dis1.75I2_angle317L4_elev15D1.png',
#  'id13-Base_p14_dis1.8I1_angle180L4_elev20D4.png',
#  'id13-Moderate_p12_dis1.7I1_angle223L1_elev15D1.png',
#  'id12-Moderate_p14_dis1.85I1_angle180R2_elev25.png',
#  'id13-Severe_p2_dis1.9_angle0R1_elev20D2.png',
#  'id6-Severe_p13_dis1.95I3_angle180L2_elev15U2.png',
#  'id8-Severe_p7_dis1.75I5_angle40R1_elev30D2.png',
#  'id2-Moderate_p4_dis1.75O3_angle317L3_elev15D4.png',
#  'id26-Severe_p5_dis1.5O3_angle73R3_elev30U2.png',
#  'id10-Base_p13_dis1.95O4_angle180R3_elev15D4.png',
#  'id12-Severe_p4_dis1.8O2_angle317L2_elev15U1.png',
#  'id26-Severe_p7_dis1.75I3_angle40R3_elev30.png',
#  'id2-Severe_p3_dis1.75I1_angle43R2_elev15.png',
#  'id12-Base_p14_dis1.85O5_angle180_elev25D3.png',
#  'id14-Moderate_p15_dis1.8I4_angle0R4_elev110.png',
#  'id8-Moderate_p12_dis1.75I3_angle223L3_elev15U4.png',
#  'id10-Severe_p14_dis1.95I5_angle180L2_elev20.png',
#  'id14-Moderate_p4_dis1.8O5_angle317L1_elev15D1.png',
#  'id8-Severe_p2_dis1.85O3_angle0L3_elev20D4.png',
#  'id14-Moderate_p3_dis1.8O5_angle43L1_elev15.png',
#  'id8-Minor_p4_dis1.8I1_angle317L2_elev15D3.png',
#  'id26-Base_p4_dis1.8_angle317R4_elev15U1.png',
#  'id26-Minor_p5_dis1.5O4_angle73R4_elev30U2.png',
#  'id10-Severe_p2_dis1.9I3_angle0L2_elev20U2.png',
#  'id14-Severe_p11_dis1.75_angle137L2_elev15D3.png',
#  'id10-Severe_p8_dis1.75I4_angle320R2_elev30U1.png',
#  'id14-Minor_p14_dis1.95_angle180R1_elev20U2.png',
#  'id13-Severe_p14_dis1.8I2_angle180R1_elev20U1.png',
#  'id6-Minor_p3_dis1.8O5_angle43L2_elev15U4.png',
#  'id13-Base_p15_dis1.8O4_angle0R2_elev110U2.png',
#  'id26-Severe_p8_dis1.75O1_angle320L4_elev30.png',
#  'id2-Base_p15_dis1.8I2_angle0R4_elev110D4.png',
#  'id10-Minor_p14_dis1.95I1_angle180L2_elev20U3.png',
#  'id10-Severe_p5_dis1.5O4_angle73R1_elev30D3.png',
#  'id14-Base_p11_dis1.75O4_angle137_elev15D3.png',
#  'id12-Base_p14_dis1.85_angle180L1_elev25D3.png',
#  'id8-Base_p6_dis1.5I4_angle287L3_elev30U3.png',
#  'id6-Base_p13_dis1.95O2_angle180L3_elev15D3.png',
#  'id14-Moderate_p4_dis1.8O5_angle317R1_elev15D3.png',
#  'id12-Moderate_p1_dis1.85O1_angle0L1_elev8D1.png',
#  'id26-Severe_p9_dis1.65O1_angle107R2_elev30U3.png',
#  'id10-Minor_p11_dis1.75O4_angle137R1_elev15D2.png',
#  'id2-Severe_p5_dis1.5O4_angle73_elev30U1.png',
#  'id10-Base_p14_dis1.95I4_angle180L4_elev20D4.png',
#  'id26-Base_p7_dis1.75O1_angle40R2_elev30D3.png',
#  'id12-Severe_p10_dis1.65_angle253L4_elev35D1.png',
#  'id12-Severe_p15_dis1.8I2_angle0L2_elev110D3.png',
#  'id26-Base_p5_dis1.5O3_angle73R1_elev30U3.png',
#  'id13-Minor_p2_dis1.9I3_angle0R2_elev20U2.png',
#  'id2-Moderate_p15_dis1.8I3_angle0L3_elev110D3.png',
#  'id8-Base_p1_dis1.85O1_angle0L4_elev8D3.png',
#  'id26-Severe_p6_dis1.5O1_angle287_elev30U1.png',
#  'id26-Minor_p8_dis1.75O5_angle320_elev30D1.png',
#  'id2-Severe_p4_dis1.75I1_angle317L4_elev15U4.png',
#  'id2-Severe_p14_dis1.8I1_angle180R1_elev20D1.png',
#  'id26-Base_p5_dis1.5O2_angle73L4_elev30.png',
#  'id10-Minor_p5_dis1.5O3_angle73R2_elev30D3.png',
#  'id8-Severe_p11_dis1.75I2_angle137L1_elev15U2.png',
#  'id10-Moderate_p7_dis1.75O1_angle40R3_elev30U1.png',
#  'id10-Minor_p11_dis1.75I4_angle137R1_elev15U4.png',
#  'id26-Severe_p3_dis1.8I2_angle43R2_elev15.png',
#  'id13-Base_p15_dis1.8I3_angle0L1_elev110U2.png',
#  'id26-Base_p5_dis1.5O1_angle73R3_elev30U4.png',
#  'id13-Severe_p13_dis1.8I4_angle180R2_elev15.png',
#  'id12-Base_p6_dis1.5I5_angle287L3_elev35D1.png',
#  'id13-Moderate_p2_dis1.9I2_angle0R1_elev20D2.png',
#  'id12-Severe_p1_dis1.85I3_angle0L1_elev8U3.png',
#  'id12-Moderate_p14_dis1.85_angle180L4_elev25U3.png',
#  'id8-Base_p2_dis1.85I4_angle0R2_elev20D1.png',
#  'id26-Severe_p6_dis1.5I4_angle287R2_elev30U3.png',
#  'id12-Minor_p5_dis1.5O1_angle73R2_elev35D2.png',
#  'id10-Severe_p4_dis1.8I2_angle317R2_elev15D4.png',
#  'id12-Severe_p6_dis1.5I5_angle287R1_elev35.png',
#  'id12-Base_p2_dis1.85O1_angle0L1_elev20.png',
#  'id6-Moderate_p3_dis1.8I1_angle43R1_elev15U1.png',
#  'id14-Base_p15_dis1.8O3_angle0R4_elev110.png',
#  'id6-Base_p8_dis1.75I1_angle320L1_elev30D3.png',
#  'id12-Minor_p9_dis1.65O4_angle107R2_elev35D1.png',
#  'id8-Minor_p12_dis1.75_angle223_elev15.png',
#  'id10-Minor_p14_dis1.95_angle180_elev20U2.png',
#  'id14-Severe_p2_dis1.95I5_angle0L2_elev20D4.png',
#  'id26-Severe_p7_dis1.75_angle40L3_elev30.png',
#  'id13-Severe_p15_dis1.8O5_angle0L3_elev110U4.png',
#  'id2-Base_p4_dis1.75O3_angle317L4_elev15D4.png',
#  'id14-Moderate_p4_dis1.8O3_angle317L1_elev15D4.png',
#  'id6-Base_p4_dis1.8O2_angle317L4_elev15D2.png',
#  'id26-Moderate_p12_dis1.75O4_angle223L3_elev15D3.png',
#  'id14-Minor_p15_dis1.8I2_angle0_elev110D4.png',
#  'id2-Severe_p3_dis1.75I5_angle43L2_elev15D2.png',
#  'id6-Severe_p6_dis1.5O4_angle287L2_elev30U1.png',
#  'id8-Severe_p3_dis1.8I1_angle43L3_elev15U1.png',
#  'id26-Severe_p13_dis1.85_angle180L1_elev15D1.png',
#  'id10-Moderate_p3_dis1.8I2_angle43L4_elev15.png',
#  'id12-Base_p7_dis1.75_angle40_elev30D2.png',
#  'id26-Moderate_p1_dis1.85I5_angle0R3_elev8D3.png',
#  'id14-Severe_p13_dis1.95I2_angle180R1_elev15D4.png',
#  'id2-Moderate_p8_dis1.7O3_angle320R1_elev30D3.png',
#  'id8-Base_p4_dis1.8_angle317R2_elev15D4.png',
#  'id13-Minor_p11_dis1.7O5_angle137R2_elev15D1.png',
#  'id12-Severe_p6_dis1.5O2_angle287R3_elev35D2.png',
#  'id8-Base_p6_dis1.5O3_angle287L2_elev30D2.png',
#  'id2-Moderate_p6_dis1.5_angle287L4_elev30D4.png',
#  'id26-Severe_p7_dis1.75I3_angle40L3_elev30.png',
#  'id26-Base_p8_dis1.75I2_angle320L3_elev30D1.png',
#  'id8-Severe_p4_dis1.8_angle317_elev15U2.png',
#  'id14-Severe_p12_dis1.75I1_angle223R1_elev15U3.png',
#  'id12-Severe_p15_dis1.8O3_angle0L1_elev110U3.png',
#  'id13-Moderate_p2_dis1.9O3_angle0L1_elev20U3.png',
#  'id6-Severe_p11_dis1.75I2_angle137R2_elev15D1.png',
#  'id8-Minor_p7_dis1.75I2_angle40_elev30D3.png',
#  'id26-Minor_p10_dis1.65I2_angle253R3_elev30U3.png',
#  'id6-Base_p12_dis1.75O1_angle223L2_elev15U3.png',
#  'id2-Minor_p14_dis1.8O1_angle180_elev20D2.png',
#  'id10-Severe_p15_dis1.8_angle0L4_elev110U3.png',
#  'id14-Minor_p10_dis1.65O2_angle253R2_elev30D4.png',
#  'id8-Base_p10_dis1.65O3_angle253R3_elev30D4.png',
#  'id12-Moderate_p8_dis1.75I2_angle320R2_elev30D1.png',
#  'id12-Severe_p2_dis1.85O5_angle0L4_elev20D4.png',
#  'id12-Severe_p2_dis1.85_angle0R2_elev20U4.png',
#  'id14-Base_p7_dis1.8I2_angle40L3_elev30U4.png',
#  'id6-Severe_p11_dis1.75O1_angle137L1_elev15D1.png',
#  'id14-Base_p4_dis1.8O2_angle317R2_elev15U1.png',
#  'id14-Moderate_p10_dis1.65O1_angle253R2_elev30D2.png',
#  'id10-Severe_p11_dis1.75O1_angle137L2_elev15U3.png',
#  'id14-Moderate_p1_dis1.95_angle0L3_elev8.png',
#  'id13-Severe_p4_dis1.8I5_angle317L2_elev15U2.png',
#  'id10-Minor_p13_dis1.95I3_angle180R3_elev15D4.png',
#  'id2-Moderate_p6_dis1.5I2_angle287L1_elev30.png',
#  'id26-Base_p11_dis1.75O3_angle137R1_elev15U2.png',
#  'id10-Base_p13_dis1.95I4_angle180L4_elev15.png',
#  'id13-Severe_p7_dis1.75I4_angle40L3_elev30U4.png',
#  'id2-Moderate_p2_dis1.8O2_angle0L2_elev20D2.png',
#  'id14-Base_p2_dis1.95O2_angle0R1_elev20D4.png',
#  'id14-Moderate_p15_dis1.8O2_angle0R2_elev110U1.png',
#  'id14-Minor_p7_dis1.8O2_angle40L1_elev30D2.png',
#  'id12-Moderate_p10_dis1.65I5_angle253R1_elev35D3.png',
#  'id13-Minor_p1_dis1.9I1_angle0L1_elev8U4.png',
#  'id12-Minor_p9_dis1.65O3_angle107L4_elev35D2.png',
#  'id13-Minor_p14_dis1.8O2_angle180L4_elev20U4.png',
#  'id14-Moderate_p8_dis1.8_angle320L1_elev30D2.png',
#  'id26-Base_p6_dis1.5I4_angle287L4_elev30U2.png',
#  'id13-Base_p12_dis1.7O5_angle223R3_elev15U4.png',
#  'id14-Base_p7_dis1.8I3_angle40R4_elev30D3.png',
#  'id13-Base_p7_dis1.75O2_angle40L1_elev30.png',
#  'id2-Moderate_p6_dis1.5O4_angle287L2_elev30U2.png',
#  'id2-Moderate_p6_dis1.5I5_angle287L2_elev30D1.png',
#  'id10-Moderate_p12_dis1.75I3_angle223L1_elev15U4.png',
#  'id8-Base_p1_dis1.85O2_angle0_elev8U4.png',
#  'id26-Severe_p13_dis1.85_angle180L1_elev15U1.png',
#  'id14-Severe_p6_dis1.5O3_angle287R3_elev30U4.png',
#  'id10-Severe_p4_dis1.8I2_angle317L2_elev15D3.png',
#  'id14-Base_p11_dis1.75O5_angle137L2_elev15D4.png',
#  'id8-Base_p12_dis1.75I2_angle223L2_elev15U3.png',
#  'id13-Moderate_p14_dis1.8O3_angle180R2_elev20U3.png',
#  'id2-Base_p4_dis1.75O1_angle317L4_elev15U4.png',
#  'id2-Severe_p14_dis1.8I5_angle180R2_elev20U4.png',
#  'id13-Minor_p13_dis1.8O2_angle180R4_elev15.png',
#  'id13-Base_p4_dis1.8O3_angle317R4_elev15U1.png',
#  'id26-Moderate_p6_dis1.5O2_angle287L4_elev30D3.png',
#  'id2-Severe_p7_dis1.7I5_angle40_elev30U2.png',
#  'id26-Moderate_p5_dis1.5_angle73_elev30U4.png',
#  'id2-Minor_p1_dis1.8I4_angle0R3_elev8D4.png',
#  'id14-Minor_p2_dis1.95I2_angle0R1_elev20U1.png',
#  'id10-Moderate_p3_dis1.8O1_angle43R1_elev15D1.png',
#  'id8-Moderate_p11_dis1.75O3_angle137L4_elev15U4.png',
#  'id26-Moderate_p2_dis1.85I5_angle0L4_elev20U4.png',
#  'id13-Base_p15_dis1.8O5_angle0L3_elev110U4.png',
#  'id6-Severe_p6_dis1.5I5_angle287L1_elev30U4.png',
#  'id26-Severe_p5_dis1.5O3_angle73_elev30D4.png',
#  'id6-Moderate_p5_dis1.5O1_angle73L2_elev30U4.png',
#  'id2-Moderate_p5_dis1.5_angle73L4_elev30U4.png',
#  'id8-Minor_p9_dis1.65O1_angle107R2_elev30D3.png',
#  'id10-Minor_p4_dis1.8I3_angle317R3_elev15D1.png',
#  'id12-Moderate_p6_dis1.5O2_angle287L2_elev35D4.png',
#  'id14-Moderate_p4_dis1.8I5_angle317L3_elev15.png',
#  'id12-Severe_p11_dis1.75O1_angle137L3_elev15U3.png',
#  'id14-Base_p12_dis1.75O2_angle223R4_elev15D2.png',
#  'id14-Moderate_p12_dis1.75I2_angle223L3_elev15U3.png',
#  'id26-Severe_p15_dis1.8I1_angle0_elev110U3.png',
#  'id8-Minor_p3_dis1.8I1_angle43R2_elev15.png',
#  'id6-Severe_p2_dis1.9O4_angle0R1_elev20.png',
#  'id10-Base_p2_dis1.9I3_angle0L1_elev20D1.png',
#  'id10-Base_p13_dis1.95O5_angle180L3_elev15D2.png',
#  'id13-Base_p2_dis1.9O4_angle0R3_elev20U4.png',
#  'id13-Base_p13_dis1.8O3_angle180L1_elev15U4.png',
#  'id14-Moderate_p15_dis1.8I5_angle0_elev110U2.png',
#  'id8-Severe_p8_dis1.75O5_angle320_elev30D1.png',
#  'id8-Base_p6_dis1.5I4_angle287L1_elev30.png',
#  'id6-Minor_p8_dis1.75I2_angle320_elev30U2.png',
#  'id12-Base_p14_dis1.85I5_angle180R2_elev25U2.png',
#  'id12-Severe_p10_dis1.65O5_angle253R3_elev35U4.png',
#  'id2-Severe_p1_dis1.8O4_angle0L4_elev8D1.png',
#  'id12-Severe_p7_dis1.75I1_angle40R3_elev30D2.png',
#  'id13-Moderate_p3_dis1.8_angle43R1_elev15.png',
#  'id2-Severe_p11_dis1.7I3_angle137_elev15.png',
#  'id6-Minor_p5_dis1.5O2_angle73L1_elev30D4.png',
#  'id12-Moderate_p11_dis1.75O2_angle137_elev15.png',
#  'id8-Moderate_p5_dis1.5I5_angle73_elev30D4.png',
#  'id26-Minor_p10_dis1.65I2_angle253R2_elev30U1.png',
#  'id26-Severe_p14_dis1.85O2_angle180R4_elev20D4.png',
#  'id14-Minor_p10_dis1.65O2_angle253_elev30.png',
#  'id26-Base_p9_dis1.65I5_angle107L3_elev30D1.png',
#  'id14-Moderate_p7_dis1.8O2_angle40R1_elev30D4.png',
#  'id26-Severe_p5_dis1.5O2_angle73R3_elev30D2.png',
#  'id14-Minor_p9_dis1.65I2_angle107_elev30D4.png',
#  'id2-Base_p8_dis1.7I1_angle320L2_elev30U1.png',
#  'id10-Minor_p13_dis1.95O1_angle180L3_elev15U3.png',
#  'id10-Moderate_p15_dis1.8I3_angle0R4_elev110D3.png',
#  'id14-Moderate_p10_dis1.65I3_angle253R3_elev30U4.png',
#  'id8-Moderate_p10_dis1.65I2_angle253L1_elev30D4.png',
#  'id10-Base_p4_dis1.8I3_angle317R3_elev15D3.png',
#  'id14-Minor_p2_dis1.95O2_angle0R3_elev20U4.png',
#  'id8-Base_p7_dis1.75_angle40L3_elev30.png',
#  'id26-Severe_p9_dis1.65I2_angle107L3_elev30U4.png',
#  'id12-Severe_p1_dis1.85_angle0L1_elev8D3.png',
#  'id12-Minor_p3_dis1.8_angle43R1_elev15U1.png',
#  'id26-Severe_p3_dis1.8O2_angle43L4_elev15U2.png',
#  'id13-Minor_p4_dis1.8O3_angle317R4_elev15U1.png',
#  'id6-Moderate_p13_dis1.95I2_angle180R3_elev15D3.png',
#  'id26-Base_p12_dis1.75O2_angle223L4_elev15.png',
#  'id6-Base_p15_dis1.8I5_angle0_elev110U4.png',
#  'id26-Base_p5_dis1.5O3_angle73L1_elev30D2.png',
#  'id13-Severe_p12_dis1.7I5_angle223L1_elev15U4.png',
#  'id2-Minor_p4_dis1.75O4_angle317R3_elev15D3.png',
#  'id12-Moderate_p12_dis1.75O4_angle223R3_elev15D4.png',
#  'id13-Moderate_p13_dis1.8I4_angle180R4_elev15U4.png',
#  'id6-Severe_p8_dis1.75O5_angle320_elev30U2.png',
#  'id10-Moderate_p8_dis1.75I2_angle320R4_elev30D1.png',
#  'id10-Severe_p13_dis1.95_angle180_elev15D1.png',
#  'id26-Minor_p14_dis1.85_angle180L1_elev20D3.png',
#  'id8-Base_p13_dis1.85I3_angle180R2_elev15U4.png',
#  'id6-Base_p12_dis1.75O2_angle223L1_elev15.png',
#  'id8-Base_p2_dis1.85O3_angle0L2_elev20.png',
#  'id14-Severe_p4_dis1.8O4_angle317L4_elev15D4.png',
#  'id10-Moderate_p15_dis1.8I2_angle0_elev110D2.png',
#  'id8-Moderate_p15_dis1.8O3_angle0R1_elev110D4.png',
#  'id26-Moderate_p6_dis1.5_angle287R3_elev30D1.png',
#  'id14-Moderate_p13_dis1.95O4_angle180R2_elev15.png',
#  'id2-Moderate_p7_dis1.7O1_angle40R4_elev30D4.png',
#  'id13-Base_p5_dis1.5I5_angle73L2_elev30.png',
#  'id6-Moderate_p14_dis1.95O3_angle180R1_elev20D3.png',
#  'id10-Base_p5_dis1.5O2_angle73R1_elev30D4.png',
#  'id14-Moderate_p9_dis1.65I3_angle107R4_elev30U1.png',
#  'id6-Base_p15_dis1.8O2_angle0R4_elev110D1.png',
#  'id10-Severe_p3_dis1.8I1_angle43L1_elev15D2.png',
#  'id13-Base_p1_dis1.9_angle0_elev8U2.png',
#  'id2-Minor_p12_dis1.7I4_angle223R4_elev15U1.png',
#  'id8-Severe_p6_dis1.5O3_angle287R2_elev30D4.png',
#  'id12-Severe_p1_dis1.85I3_angle0L3_elev8D1.png',
#  'id10-Minor_p8_dis1.75O1_angle320L1_elev30.png',
#  'id26-Base_p6_dis1.5_angle287L4_elev30D2.png',
#  'id14-Severe_p9_dis1.65O2_angle107R1_elev30.png',
#  'id12-Moderate_p13_dis1.85O1_angle180_elev15U4.png',
#  'id12-Minor_p11_dis1.75O3_angle137R1_elev15D2.png',
#  'id8-Base_p6_dis1.5I5_angle287_elev30U3.png',
#  'id8-Severe_p7_dis1.75O5_angle40R3_elev30D2.png',
#  'id10-Moderate_p8_dis1.75I2_angle320L4_elev30D3.png',
#  'id14-Base_p13_dis1.95O2_angle180L4_elev15U2.png',
#  'id2-Severe_p7_dis1.7O5_angle40L1_elev30U4.png',
#  'id6-Moderate_p4_dis1.8O3_angle317R3_elev15D1.png',
#  'id14-Moderate_p6_dis1.5O5_angle287R3_elev30U2.png',
#  'id12-Moderate_p7_dis1.75I4_angle40L4_elev30D2.png',
#  'id26-Minor_p3_dis1.8O2_angle43R3_elev15U4.png',
#  'id6-Base_p1_dis1.9O1_angle0L2_elev8U1.png',
#  'id6-Minor_p5_dis1.5_angle73L3_elev30D2.png',
#  'id14-Base_p1_dis1.95I4_angle0R4_elev8D1.png',
#  'id8-Minor_p10_dis1.65_angle253R2_elev30U1.png',
#  'id6-Moderate_p8_dis1.75I5_angle320_elev30D1.png',
#  'id14-Severe_p14_dis1.95O1_angle180R3_elev20D4.png',
#  'id12-Severe_p12_dis1.75O1_angle223R2_elev15U2.png',
#  'id13-Moderate_p6_dis1.5O4_angle287R2_elev30U2.png',
#  'id13-Severe_p5_dis1.5I5_angle73L1_elev30D1.png',
#  'id12-Base_p4_dis1.8I5_angle317L3_elev15D4.png',
#  'id13-Severe_p11_dis1.7_angle137L2_elev15D2.png',
#  'id12-Base_p2_dis1.85_angle0R3_elev20D3.png',
#  'id8-Base_p13_dis1.85O5_angle180R1_elev15D4.png',
#  'id14-Moderate_p3_dis1.8O2_angle43_elev15U1.png',
#  'id6-Moderate_p12_dis1.75I4_angle223L4_elev15D3.png',
#  'id6-Moderate_p1_dis1.9I3_angle0L4_elev8D3.png',
#  'id2-Severe_p15_dis1.8O2_angle0_elev110D3.png',
#  'id13-Base_p7_dis1.75I4_angle40R3_elev30U4.png',
#  'id2-Base_p11_dis1.7_angle137L3_elev15U3.png',
#  'id10-Minor_p14_dis1.95I4_angle180R1_elev20U1.png',
#  'id10-Base_p5_dis1.5I1_angle73R3_elev30U2.png',
#  'id2-Moderate_p5_dis1.5_angle73L2_elev30U2.png',
#  'id14-Minor_p8_dis1.8I2_angle320L1_elev30.png',
#  'id8-Minor_p9_dis1.65_angle107R1_elev30U4.png',
#  'id14-Moderate_p2_dis1.95I5_angle0R1_elev20U3.png',
#  'id10-Moderate_p2_dis1.9O4_angle0_elev20U2.png',
#  'id6-Severe_p3_dis1.8O1_angle43R2_elev15D3.png',
#  'id12-Base_p1_dis1.85I2_angle0R4_elev8U3.png',
#  'id10-Base_p8_dis1.75I3_angle320R2_elev30D2.png',
#  'id8-Moderate_p10_dis1.65O1_angle253_elev30D4.png',
#  'id12-Moderate_p14_dis1.85_angle180R3_elev25.png',
#  'id12-Moderate_p14_dis1.85O2_angle180L3_elev25D4.png',
#  'id8-Base_p4_dis1.8I5_angle317_elev15D2.png',
#  'id10-Minor_p11_dis1.75I4_angle137_elev15U2.png',
#  'id10-Base_p6_dis1.5I3_angle287_elev30D4.png',
#  'id10-Severe_p14_dis1.95O2_angle180R3_elev20.png',
#  'id6-Severe_p1_dis1.9I2_angle0R4_elev8U3.png',
#  'id26-Moderate_p11_dis1.75I1_angle137R2_elev15U2.png',
#  'id26-Minor_p10_dis1.65I1_angle253R3_elev30.png',
#  'id14-Moderate_p13_dis1.95I3_angle180R2_elev15U1.png',
#  'id8-Minor_p13_dis1.85I3_angle180L4_elev15D3.png',
#  'id2-Moderate_p3_dis1.75I5_angle43L4_elev15D1.png',
#  'id12-Minor_p1_dis1.85I2_angle0R1_elev8D1.png',
#  'id8-Severe_p14_dis1.85O4_angle180R2_elev20D3.png',
#  'id26-Severe_p3_dis1.8_angle43R1_elev15U4.png',
#  'id14-Minor_p14_dis1.95I4_angle180L4_elev20U4.png',
#  'id13-Base_p7_dis1.75I1_angle40R2_elev30D2.png',
#  'id8-Severe_p9_dis1.65I3_angle107L1_elev30D4.png',
#  'id13-Severe_p6_dis1.5I1_angle287R4_elev30D1.png',
#  'id26-Base_p4_dis1.8I4_angle317_elev15U4.png',
#  'id8-Moderate_p6_dis1.5O5_angle287R2_elev30.png',
#  'id6-Moderate_p3_dis1.8O4_angle43L1_elev15D4.png',
#  'id8-Moderate_p8_dis1.75I4_angle320L3_elev30D1.png',
#  'id10-Minor_p11_dis1.75I5_angle137L2_elev15U4.png',
#  'id14-Severe_p1_dis1.95I2_angle0_elev8U1.png',
#  'id12-Moderate_p7_dis1.75O4_angle40R2_elev30D1.png',
#  'id6-Moderate_p8_dis1.75I4_angle320L3_elev30U3.png',
#  'id6-Minor_p3_dis1.8O2_angle43R4_elev15U2.png',
#  'id26-Minor_p9_dis1.65I4_angle107L1_elev30.png',
#  'id26-Base_p11_dis1.75O1_angle137L1_elev15U3.png',
#  'id13-Base_p14_dis1.8_angle180R1_elev20.png',
#  'id14-Moderate_p9_dis1.65O1_angle107R3_elev30D1.png',
#  'id14-Moderate_p8_dis1.8O3_angle320R1_elev30D4.png',
#  'id6-Minor_p13_dis1.95I3_angle180L4_elev15D2.png',
#  'id14-Severe_p5_dis1.5I4_angle73L1_elev30.png',
#  'id13-Severe_p2_dis1.9I1_angle0R3_elev20U1.png',
#  'id13-Moderate_p15_dis1.8O2_angle0L1_elev110U2.png',
#  'id2-Moderate_p13_dis1.8O5_angle180R4_elev15D3.png',
#  'id26-Moderate_p10_dis1.65O1_angle253L3_elev30D3.png',
#  'id13-Severe_p13_dis1.8I1_angle180_elev15D3.png',
#  'id8-Moderate_p7_dis1.75I2_angle40L1_elev30U3.png',
#  'id12-Moderate_p6_dis1.5O4_angle287R4_elev35U4.png',
#  'id13-Base_p4_dis1.8O5_angle317R4_elev15.png',
#  'id2-Moderate_p3_dis1.75I3_angle43R3_elev15D2.png',
#  'id12-Moderate_p5_dis1.5I3_angle73_elev35D3.png',
#  'id14-Base_p9_dis1.65I2_angle107L3_elev30D2.png',
#  'id2-Minor_p8_dis1.7O3_angle320L2_elev30D1.png',
#  ...]

# %%
file_path
# Out:
# '/media/SSD/Data_photogram_Pcar/8-Fold/id6-Minor_p2_dis1.9O5_angle0R1_elev20D1.png/id6-Base_p13_dis1.95O3_angle180L1_elev15D1.png'

# %%
file_path
# Out:
# '/media/SSD/Data_photogram_Pcar/8-Fold/id26-Moderate_p6_dis1.5O2_angle287L1_elev30U3.png'
